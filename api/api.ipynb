# %%
import requests
import json
# "한겨레","조선일보","중앙일보","동아일보","경향신문","서울일보","KBS","MBC","SBS","YTN"

# %% [markdown]
# # 2. 뉴스 검색 API

# %%
url = 'http://tools.kinds.or.kr:8888/search/news'

datas = {
    "access_key": "9af2f705-2974-4340-8b55-d69040b944ab",

    "argument": {
        "query": "오징어게임",
        "published_at": {
            "from": "2012-01-01",
            "until": "2021-10-01"
            },
            "provider": ["한겨레","조선일보","중앙일보","동아일보","경향신문","서울일보","KBS","MBC","SBS","YTN"],
            "category": ["IT_과학>콘텐츠"],
            "category_incident": [""],
            "byline": "",
            "provider_subject": [""],
            "subject_info": [""],
            "subject_info1": [""],
            "subject_info2": [""],
            "subject_info3": [""],
            "subject_info4": [""],
            "sort": {"date": "asc"},
            "hilight": 200,
            "return_from": 0,
            "return_size": 1000,
            "fields": [
                "byline",
                "category",
                "category_incident",
                "provider_news_id",
                "hilight",
                ]
                }
         }

response = requests.post(url, data=json.dumps(datas))
js=response.json()

js
# Out:
# {'result': 0,
#  'return_object': {'documents': [{'byline': '최보란',
#     'category': ['IT_과학>콘텐츠', '문화>방송_연예', '문화>영화'],
#     'category_incident': [],
#     'dateline': '2019-11-14T11:12:03.000+09:00',
#     'enveloped_at': '2019-11-14T11:12:03.000+09:00',
#     'hilight': '이정재 측 .."넷플릭스 ..\'<b>오징어게임</b>\', 제안 받고 검토중"(공식입장) 배우 이정재가 넷플릭스 오리지널 시리즈 ..\'오징어 게임\' 출연을 검토 중이다. .. ..이정재의 소속사 아티스트컴퍼니 관계자는 14일 .."이정재 씨가 출연을 제안 받고 검토 중인 단계"라고 밝혔다. .. ..\'오징어 게임\'은 인생의 패배자로 살아가고 있는 사람들이 100억원의..',
#     'news_id': '08100401.20191114111203001',
#     'provider': 'YTN',
#     'provider_news_id': '201911141111342145',
#     'published_at': '2019-11-14T00:00:00.000+09:00',
#     'title': '이정재 측 "넷플릭스 \'오징어게임\', 제안 받고 검토중"(공식입장)'},
#    {'byline': '최보란',
#     'category': ['문화>영화', 'IT_과학>콘텐츠', '문화>방송_연예'],
#     'category_incident': [],
#     'dateline': '2020-03-11T10:44:02.000+09:00',
#     'enveloped_at': '2020-03-11T10:10:04.000+09:00',
#     'hilight': "'<b>오징어게임</b>' 이정재X박해수 캐스팅 확정...기대되는 시너지 ..(공식) 넷플릭스(Netflix)가 황동혁 감독이 연출하는 새로운 오리지널 시리즈 ..'오징어 게임'의 주요 캐스팅을 확정했다. .. ..배우 이정재와 박해수가 황동혁 감독의 넷플릭스 오리지널 시리즈 ..'오징어 게임'에 합류한다... ..'오징어 게임'은 456억 원의 상금이 걸린 의문의..",
#     'news_id': '08100401.20200311101004001',
#     'provider': 'YTN',
#     'provider_news_id': '202003111008082649',
#     'published_at': '2020-03-11T00:00:00.000+09:00',
#     'title': "'오징어게임' 이정재X박해수 캐스팅 확정...기대되는 시너지 (공식)"},
#    {'byline': 'YTN',
#     'category': ['IT_과학>콘텐츠', '문화>영화', '사회>미디어'],
#     'category_incident': [],
#     'dateline': '2020-08-21T18:06:04.000+09:00',
#     'enveloped_at': '2020-08-21T18:06:04.000+09:00',
#     'hilight': "방송가 코로나19 비상...드라마 촬영 잇따라 중단 방송사들이 드라마 촬영을 잇따라 중단하는 등 코로나 19 대응에 비상이 걸렸습니다. .. ..어제(20일) 확진자와 접촉자가 발생해 대대적으로 방역을 실시한 JTBC는 수도권에서 진행하는 6개 드라마 촬영을 중단했습니다...'<b>오징어게임</b>' 등 한국 오리지널 콘텐츠의 모든 제작 일정을 중단하기로 했습니다...",
#     'news_id': '08100401.20200821180604001',
#     'provider': 'YTN',
#     'provider_news_id': '202008211805308004',
#     'published_at': '2020-08-21T00:00:00.000+09:00',
#     'title': '방송가 코로나19 비상...드라마 촬영 잇따라 중단'},
#    {'byline': '이유나',
#     'category': ['문화>영화', '문화>방송_연예', 'IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-08-27T11:02:02.000+09:00',
#     'enveloped_at': '2021-08-27T11:02:02.000+09:00',
#     'hilight': "[Y초점] ..'D.P'-'<b>오징어게임</b>'-'지옥'...하반기 야심작 대방출하는 넷플릭스 OTT 경쟁이 날로 심해지는 가운데, 넷플릭스가 올 하반기 K콘텐츠 기대작들을 대방출하며 업계 1위의 위엄을 떨칠 전망이다. .. ..글로벌 OTT 기업 넷플릭스에 있어 대한민국은 아시아 시장 전체를 겨냥하는 ..'콘텐츠 생산기지'다... 2016년 한국 진출 후 지난..",
#     'news_id': '08100401.20210827110202001',
#     'provider': 'YTN',
#     'provider_news_id': '202108271059577466',
#     'published_at': '2021-08-27T00:00:00.000+09:00',
#     'title': "[Y초점] 'D.P'-'오징어게임'-'지옥'...하반기 야심작 대방출하는 넷플릭스"},
#    {'byline': '이유나',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-15T11:16:04.000+09:00',
#     'enveloped_at': '2021-09-15T11:16:04.000+09:00',
#     'hilight': '\'<b>오징어게임</b>\' 이정재 .."게임 어떻게 구현될까 궁금...세트장 가는날 기대" 넷플릭스 ..\'오징어 게임\'에 출연한 이정재가 작품에 참여한 이유를 밝혔다. .. ..15일 오전 넷플릭스 시리즈 ..\'오징어 게임\'의 온라인 제작발표회가 개최됐다... 이날 현장에는 시리즈에 출연한 배우 이정재, 박해수, 위하준, 정호연, 허성태와 황동혁 감독이 참석해 작품..',
#     'news_id': '08100401.20210915111604003',
#     'provider': 'YTN',
#     'provider_news_id': '202109151114471151',
#     'published_at': '2021-09-15T00:00:00.000+09:00',
#     'title': '\'오징어게임\' 이정재 "게임 어떻게 구현될까 궁금...세트장 가는날 기대"'},
#    {'byline': '이유나',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-15T11:22:03.000+09:00',
#     'enveloped_at': '2021-09-15T11:22:03.000+09:00',
#     'hilight': '\'<b>오징어게임</b>\' 이정재 .."드라마 속 내 모습 무서웠다...뇌가 없나 싶어" 웃음 ..\'오징어 게임\' 이정재가 .. .. ..15일 오전 넷플릭스 시리즈 ..\'오징어 게임\'의 온라인 제작발표회가 개최됐다... 이날 현장에는 시리즈에 출연한 배우 이정재, 박해수, 위하준, 정호연, 허성태와 황동혁 감독이 참석해 작품과 관련된 다양한 이야기를 나눴다. ..',
#     'news_id': '08100401.20210915112203003',
#     'provider': 'YTN',
#     'provider_news_id': '202109151121332047',
#     'published_at': '2021-09-15T00:00:00.000+09:00',
#     'title': '\'오징어게임\' 이정재 "드라마 속 내 모습 무서웠다...뇌가 없나 싶어" 웃음'},
#    {'byline': '이유나',
#     'category': ['문화>방송_연예', '문화>영화', 'IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-15T11:26:06.000+09:00',
#     'enveloped_at': '2021-09-15T11:26:06.000+09:00',
#     'hilight': '\'<b>오징어게임</b>\' 황동혁 감독 .."이정재, 한번 망가뜨려보고 싶어 캐스팅" 넷플릭스 ..\'오징어 게임\'을 연출한 황동혁 감독이 이정재를 캐스팅한 이유를 밝혔다. .. ..15일 오전 넷플릭스 시리즈 ..\'오징어 게임\'의 온라인 제작발표회가 개최됐다... 이날 현장에는 시리즈에 출연한 배우 이정재, 박해수, 위하준, 정호연, 허성태와 황동혁 감독이 참석해 ..',
#     'news_id': '08100401.20210915112606001',
#     'provider': 'YTN',
#     'provider_news_id': '202109151124254815',
#     'published_at': '2021-09-15T00:00:00.000+09:00',
#     'title': '\'오징어게임\' 황동혁 감독 "이정재, 한번 망가뜨려보고 싶어 캐스팅"'},
#    {'byline': '이유나',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-15T11:36:02.000+09:00',
#     'enveloped_at': '2021-09-15T11:36:02.000+09:00',
#     'hilight': '정호연 .."\'<b>오징어게임</b>\' 위해 뉴욕 패션위크 정리하고 한국행" 넷플릭스 ..\'오징어 게임\' 정호연이 뉴욕 활동 정리하고 작품에 참여한 비하인드를 밝혔다. .. ..15일 오전 넷플릭스 시리즈 ..\'오징어 게임\'의 온라인 제작발표회가 개최됐다... 이날 현장에는 시리즈에 출연한 배우 이정재, 박해수, 위하준, 정호연, 허성태와 황동혁 감독이 참석해 작품..',
#     'news_id': '08100401.20210915113602001',
#     'provider': 'YTN',
#     'provider_news_id': '202109151134092958',
#     'published_at': '2021-09-15T00:00:00.000+09:00',
#     'title': '정호연 "\'오징어게임\' 위해 뉴욕 패션위크 정리하고 한국행"'},
#    {'byline': '손효주',
#     'category': ['문화>방송_연예', '문화>영화', 'IT_과학>콘텐츠'],
#     'category_incident': ['범죄>범죄일반>폭행'],
#     'dateline': '2021-09-15T05:56:00.000+09:00',
#     'enveloped_at': '2021-09-15T15:13:15.000+09:00',
#     'hilight': '‘<b>오징어게임</b>’을 연출한 황동혁 감독은 15일 열린 온라인 제작발표회에서 이 같이 밝혔다... 1970년대, 80년대 어린이들이 자주 하던 추억의 놀이인 <b>오징어게임</b>에서 작품명을 따왔다...“<b>오징어게임</b>은 제가 어릴 적 골목에서 하던 놀이 중에 육체적으로 가장 격렬했던 놀이”라며 ....<b>오징어게임</b>이 현대 경쟁 사회를 가장 상징적으로 보여주는 게임인 거 같아 ..',
#     'news_id': '01100401.20210915151315001',
#     'provider': '동아일보',
#     'provider_news_id': '20210915.109272601.1',
#     'published_at': '2021-09-15T00:00:00.000+09:00',
#     'title': '“우리는 왜 경쟁하는가”…상금 456억 원을 위한 잔혹한 생존 게임'},
#    {'byline': '유경선 기자 lightsun@kyunghyang.com',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-15T17:06:32.000+09:00',
#     'enveloped_at': '2021-09-15T17:06:32.000+09:00',
#     'hilight': '어릴 적 골목 놀이가 피칠갑 서바이벌로…현대의 잔혹동화 ..‘<b>오징어게임</b>’ 넷플릭스가 오는 17일 공개하는 드라마 ..<오징어 게임>은 어린 시절 친구들과 함께 하던 놀이가 실제 목숨을 건 서바이벌 게임으로 둔갑하는 섬뜩한 ..‘잔혹 동화’다... 456명 중에서 살아남는 최후의 1인이 되면 456억원이라는 상금을 거머쥘 수 있다는 설정이다... .. ..',
#     'news_id': '01100101.20210915170632001',
#     'provider': '경향신문',
#     'provider_news_id': '202109151705001',
#     'published_at': '2021-09-15T00:00:00.000+09:00',
#     'title': '어릴 적 골목 놀이가 피칠갑 서바이벌로…현대의 잔혹동화 ‘오징어게임’'},
#    {'byline': '이유나',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-17T23:54:02.000+09:00',
#     'enveloped_at': '2021-09-15T20:02:02.000+09:00',
#     'hilight': "[Y리뷰] 넷플릭스 ..'<b>오징어게임</b>' 첫회부터 빠져든다 대망의 ..'<b>오징어게임</b>'이 넷플릭스에서 이틀 뒤(17일) 공개된다... 공개에 앞서 미리 시청해본 ..'<b>오징어게임</b>' 첫 회는 개성 넘치는 상큼발랄 비주얼과 핏빛 서바이벌이 거대하게 엉겨붙은 카오스 그 자체다. .. ..'오징어 게임'은 456억 원의..'<b>오징어게임</b>' 안에서 살육 서바이벌로 진화했다...",
#     'news_id': '08100401.20210915200202001',
#     'provider': 'YTN',
#     'provider_news_id': '202109152001016629',
#     'published_at': '2021-09-15T00:00:00.000+09:00',
#     'title': "[Y리뷰] 넷플릭스 '오징어게임' 첫회부터 빠져든다"},
#    {'byline': '손효주',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': ['범죄>범죄일반>폭행'],
#     'dateline': '2021-09-15T18:00:00.000+09:00',
#     'enveloped_at': '2021-09-16T03:04:12.000+09:00',
#     'hilight': '‘<b>오징어게임</b>’은 육군 헌병대의 군무이탈자 체포전담조 이야기를 다룬 .. 1970, 80년대 어린이들이 골목길에서 자주 하던 <b>오징어게임</b>에서 작품명을 따왔다.....<b>오징어게임</b>’은 참가자 456명이 우승자 1인에게 돌아가는 상금 456억 원을 놓고 <b>오징어게임</b>을 비롯한 ..“<b>오징어게임</b>은 제가 어릴 적 골목에서 하던 놀이 중 가장 경쟁적이고 격렬했던 놀이”라며 ..',
#     'news_id': '01100401.20210916030412001',
#     'provider': '동아일보',
#     'provider_news_id': '20210916.109281244.1',
#     'published_at': '2021-09-16T00:00:00.000+09:00',
#     'title': '목숨 건 오징어게임… “우린 왜 경쟁하는가”'},
#    {'byline': '이유나',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-20T14:40:02.000+09:00',
#     'enveloped_at': '2021-09-19T17:22:02.000+09:00',
#     'hilight': '[Y이슈] 넷플릭스 ..\'<b>오징어게임</b>\', 표절 의혹·시대착오적 표현 ..\'시끌\' 넷플릭스 시리즈 ..\'오징어 게임\'이 지난 금요일(17일) 추석 연휴를 앞두고..\'<b>오징어게임</b>\'은 표절 의혹, 여성에 대한 시대착오적인 표현 등 다양한 이슈가 따라붙으며 문제작으로 자리매김 중이다. .."\'<b>오징어게임</b>\'은 2008년부터 구상한 작품"이라며 오리지널리티를 주장했다...',
#     'news_id': '08100401.20210919172202002',
#     'provider': 'YTN',
#     'provider_news_id': '202109191721164310',
#     'published_at': '2021-09-19T00:00:00.000+09:00',
#     'title': "[Y이슈] 넷플릭스 '오징어게임', 표절 의혹·시대착오적 표현 '시끌'"},
#    {'byline': '이보람(lee.boram2@joongang.co.kr)',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-22T23:21:39.000+09:00',
#     'enveloped_at': '2021-09-22T12:23:58.000+09:00',
#     'hilight': "'<b>오징어게임</b>' 美넷플릭스 1위 찍은날, 이병헌이 올린 사진 배우 이병헌이 미국 넷플릭스에서 한국 최초로 1위를 차지한 넷플릭스 오리지널 드라마 ..‘오징어 게임’을 응원했다... .. .. .. .. 이병헌은 지난 21일 인스타그램에 추석 인사를 올리면서 오징어 게임 로고가 있는 게임기 모양 선물 상자와 옷, 장난감 등 선물 받은 굿즈 사진을 공유했다...",
#     'news_id': '01100901.20210922122358001',
#     'provider': '중앙일보',
#     'provider_news_id': '25008720',
#     'published_at': '2021-09-22T00:00:00.000+09:00',
#     'title': "'오징어게임' 美넷플릭스 1위 찍은날, 이병헌이 올린 사진"},
#    {'byline': '김자아 기자',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-22T13:30:29.000+09:00',
#     'enveloped_at': '2021-09-22T13:31:28.000+09:00',
#     'hilight': '이병헌, ..‘<b>오징어게임</b>’ 美 넷플릭스 1위한 날 올린 사진 넷플릭스 오리지널 드라마 ..‘오징어 게임’이 미국 넷플릭스 시청 순위 1위를 기록한 가운데, 배우 이병헌이 ..‘오징어 게임’을 응원했다... .. .. .. ..이병헌은 21일 자신의 인스타그램에 ..‘오징어 게임’ 로고가 그려진 게임기 모양 상자와 티셔츠 등 ..‘오징어 게임’ 굿즈가 담..',
#     'news_id': '01100801.20210922133128001',
#     'provider': '조선일보',
#     'provider_news_id': '2021092200370',
#     'published_at': '2021-09-22T00:00:00.000+09:00',
#     'title': '이병헌, ‘오징어게임’ 美 넷플릭스 1위한 날 올린 사진'},
#    {'byline': '배재성(hongdoya@joongang.co.kr)',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-22T23:22:39.000+09:00',
#     'enveloped_at': '2021-09-22T13:35:46.000+09:00',
#     'hilight': "‘<b>오징어게임</b>’ 완주한 정용진 ..'<b>오징어게임</b>' 시청 후기를 올렸다. ..“<b>오징어게임</b>을 완주하고 나니 갑자기 직쏘가 보고싶다...‘<b>오징어게임</b>’은 456억원의 상금이 걸린 의문의 서바이벌 게임에 참가한 사람들이 최후 승자가 되기 위해 목숨걸고 극한의 게임에 도전하는 내용이 담긴 넷플릭스의 한국드라마다...“<b>오징어게임</b>을 직접 열어달라” 등의 댓글을 달았다...",
#     'news_id': '01100901.20210922133546001',
#     'provider': '중앙일보',
#     'provider_news_id': '25008732',
#     'published_at': '2021-09-22T00:00:00.000+09:00',
#     'title': '‘오징어게임’ 완주한 정용진 “직쏘를 살려내라! 살려내라!”'},
#    {'byline': '전채은',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-22T18:00:00.000+09:00',
#     'enveloped_at': '2021-09-23T03:02:47.000+09:00',
#     'hilight': '‘<b>오징어게임</b>’ 한국 드라마 최초 美넷플릭스 1위 배우 이정재 주연의 국내 넷플릭스 드라마 ..‘<b>오징어게임</b>’(사진)이 미국 넷플릭스 TV 프로그램 1위에 올랐다...‘<b>오징어게임</b>’은 전날까지 1위였던 영국 드라마 ....<b>오징어게임</b>’은 한국, 미국을 비롯해 태국, .. 드라마는 1970, 80년대 어린이들이 골목길에서 자주 하던 <b>오징어게임</b>에서 제목을 따왔다...',
#     'news_id': '01100401.20210923030247001',
#     'provider': '동아일보',
#     'provider_news_id': '20210923.109354067.1',
#     'published_at': '2021-09-23T00:00:00.000+09:00',
#     'title': '‘오징어게임’ 한국 드라마 최초 美넷플릭스 1위'},
#    {'byline': '이경은 기자',
#     'category': ['IT_과학>콘텐츠', '문화>방송_연예', '문화>영화'],
#     'category_incident': [],
#     'dateline': '2021-09-23T10:02:35.000+09:00',
#     'enveloped_at': '2021-09-23T10:02:38.000+09:00',
#     'hilight': 'K드라마가 뜬다..... 오징어 게임株 20%대 강세 넷플릭스에서 공개된 한국 드라마 ..‘오징어 게임’이 미국에서 1위를 차지했다는 소식이 전해지면서 23일 K드라마 관련주가 강세다... .. .. .. ..이날 오전 10시 현재 쇼박스는 전날보다 20% 넘게 오른 49.. 버킷스튜디오는 <b>오징어게임</b> 주연 배우인 이정재가 속한 아티스트컴퍼니의 모회사다...',
#     'news_id': '01100801.20210923100238001',
#     'provider': '조선일보',
#     'provider_news_id': '2021092300721',
#     'published_at': '2021-09-23T00:00:00.000+09:00',
#     'title': 'K드라마가 뜬다... 오징어 게임株 20%대 강세'},
#    {'byline': '이유진 기자 yjleee@kyunghyang.com',
#     'category': ['IT_과학>모바일', 'IT_과학>콘텐츠', '경제>유통'],
#     'category_incident': [],
#     'dateline': '2021-09-23T14:40:15.000+09:00',
#     'enveloped_at': '2021-09-23T10:28:56.000+09:00',
#     'hilight': '‘D.P.’ 효과일까?···한국인들, 지난달에만 넷플릭스에 753억원 썼다 지난 8월 한국인들이 온라인동영상서비스(OTT) 넷플릭스에서 결제한 금액이 총 753억원으로 집계됐다... 월간 결제액으로는 역대 최대다. .. ..23일 앱 분석서비스 와이즈앱에..<<b>오징어게임</b>> 역시 한국 드라마 최초로 미국 넷플릭스 1위를 기록하는 등 큰 인기를 끌고 있다. ..',
#     'news_id': '01100101.20210923102856001',
#     'provider': '경향신문',
#     'provider_news_id': '202109231027001',
#     'published_at': '2021-09-23T00:00:00.000+09:00',
#     'title': '‘D.P.’ 효과일까?···한국인들, 지난달에만 넷플릭스에 753억원 썼다'},
#    {'byline': '이유나',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-23T10:48:02.000+09:00',
#     'enveloped_at': '2021-09-23T10:48:02.000+09:00',
#     'hilight': "[Y초점] ..'<b>오징어게임</b>' 위해 美 활동 포기...정호연의 현명한 선택 ..'오징어 게임'이 넷플릭스 K-콘텐츠의 역사를 새로이 쓰고 있는 가운데, 배우 정호연을 향한 전세계 넷플릭스 시청자들의 관심이 전에 없이 뜨겁다. .. ..지난 17일 넷플릭스에서 공개된 ..'오징어 게임'은 21일(현지시간) 미국 넷플릭스 전체 순위 1위를 차지하는 새 역사를..",
#     'news_id': '08100401.20210923104802001',
#     'provider': 'YTN',
#     'provider_news_id': '202109231047368153',
#     'published_at': '2021-09-23T00:00:00.000+09:00',
#     'title': "[Y초점] '오징어게임' 위해 美 활동 포기...정호연의 현명한 선택"},
#    {'byline': '이유나',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-23T13:08:03.000+09:00',
#     'enveloped_at': '2021-09-23T13:08:03.000+09:00',
#     'hilight': "'오징어 게임' 美 넷플릭스 재패 기념 미공개 스틸 대방출 넷플릭스 ..'오징어 게임'이 한국 시리즈 최초로 美 넷플릭스 ..'오늘의 Top 10' 1위는 물론 전 세계 40여 개국에서 상위권에 오르는 파란을 일으키고 있는 가운데, 미공개 스틸을 대..'<b>오징어게임</b>' 미공개 스틸은 목숨 건 게임에 참가한 이들의 절박하고 긴장감 넘치는 순간들이 담겨 있다...",
#     'news_id': '08100401.20210923130803001',
#     'provider': 'YTN',
#     'provider_news_id': '202109231307216450',
#     'published_at': '2021-09-23T00:00:00.000+09:00',
#     'title': "'오징어 게임' 美 넷플릭스 재패 기념 미공개 스틸 대방출"},
#    {'byline': '이은비',
#     'category': ['IT_과학>콘텐츠', '정치>정치일반'],
#     'category_incident': [],
#     'dateline': '2021-09-23T14:32:21.000+09:00',
#     'enveloped_at': '2021-09-23T14:32:21.000+09:00',
#     'hilight': '"목숨 안 걸어도 1억" 허경영 ..\'<b>오징어게임</b>\' 패러디 허경영 국가혁명당 명예대표가 넷플릭스 오리지널 시리즈 ..\'오징어 게임\'을 패러디한 대선 공약 포스터를 공개해 화제다. .. ..\'오징어 게임\'은 여러 가지 이유로 생긴 빚으로 인한 빈곤으로 삶의 벼랑 끝에 몰린 사람들이 456억 원의 상금을 차지하기 위해 목숨을 걸고 서바이벌 게임에 참여한다는 ..',
#     'news_id': '08100401.20210923143221001',
#     'provider': 'YTN',
#     'provider_news_id': '202109231431011725',
#     'published_at': '2021-09-23T00:00:00.000+09:00',
#     'title': '"목숨 안 걸어도 1억" 허경영 \'오징어게임\' 패러디'},
#    {'byline': '김명일 기자',
#     'category': ['IT_과학>콘텐츠', 'IT_과학>모바일'],
#     'category_incident': [],
#     'dateline': '2021-09-23T15:18:16.000+09:00',
#     'enveloped_at': '2021-09-23T15:18:42.000+09:00',
#     'hilight': '‘<b>오징어게임</b>’서 노출, 전화 수천통 왔다” 고통 호소 넷플릭스에서 공개된 한국 드라마 ..“<b>오징어게임</b> 방영 이후 일상생활이 어려울 정도로 24시간 문자와 전화가 쉴 새 없이 온다...‘<b>오징어게임</b>에 네 번호가 나온다’고 얘기를 해줘 알았다”라며 넷플릭스와 제작사인 싸이런픽쳐스에 연락을 계속해서 취했지만 연결이 되지 않아 항의조차 하지 못한 상태라고 했다...',
#     'news_id': '01100801.20210923151842001',
#     'provider': '조선일보',
#     'provider_news_id': '2021092301215',
#     'published_at': '2021-09-23T00:00:00.000+09:00',
#     'title': '“10년 쓴 내 번호 ‘오징어게임’서 노출, 전화 수천통 왔다” 고통 호소'},
#    {'byline': '김은빈(kim.eunbin@joongang.co.kr)',
#     'category': ['IT_과학>콘텐츠', 'IT_과학>모바일', 'IT_과학>보안'],
#     'category_incident': [],
#     'dateline': '2021-09-23T18:12:04.000+09:00',
#     'enveloped_at': '2021-09-23T16:16:24.000+09:00',
#     'hilight': '\'<b>오징어게임</b>\' 초대장속 그 번호…"내 전화인데" 피해자 등장 넷플릭스 오리지널 시리즈 ..\'오징어 게임\'에서 자신의 휴대전화 번호가 노출됐다며 고통을 호소하는 피해자가 등장했다... .. .. .. .. 피해자 A씨는 23일 머니투데이를 통해 자신이 사용 중인 휴대전화 번호가 ..\'오징어 게임\'에 등장한 이후부터 일상생활이 어려울 정도로 문자와 전화고 ..',
#     'news_id': '01100901.20210923161624001',
#     'provider': '중앙일보',
#     'provider_news_id': '25009075',
#     'published_at': '2021-09-23T00:00:00.000+09:00',
#     'title': '\'오징어게임\' 초대장속 그 번호…"내 전화인데" 피해자 등장'},
#    {'byline': 'YTN',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-23T17:30:03.000+09:00',
#     'enveloped_at': '2021-09-23T17:24:02.000+09:00',
#     'hilight': '얼마 전 D.P.에 이어서 넷플릭스 드라마 <b>오징어게임</b>이 추석 연휴 기간 큰 인기를 끌었습니다...예를 들어서 구슬치기라든지 줄다리기는 게임 방식을 이해하기 쉽지만 <b>오징어게임</b>은 상당히 어렵잖아요.....<b>오징어게임</b>이 굉장히 중요한 마지막 단계..직접 한번 <b>오징어게임</b>을 해 봐라, 이렇게 얘기를 했는데 사실은 현실에서 하면 이건 범죄기 때문에 하면 안 됩니다...',
#     'news_id': '08100401.20210923172402001',
#     'provider': 'YTN',
#     'provider_news_id': '202109231706528015',
#     'published_at': '2021-09-23T00:00:00.000+09:00',
#     'title': "[뉴스큐] 연휴에 난리 난 '오징어 게임'...전 세계도 빠졌다"},
#    {'byline': '김소영',
#     'category': ['IT_과학>콘텐츠', 'IT_과학>모바일', 'IT_과학>보안'],
#     'category_incident': [],
#     'dateline': '2021-09-23T08:32:00.000+09:00',
#     'enveloped_at': '2021-09-23T17:36:29.000+09:00',
#     'hilight': '“‘<b>오징어게임</b>’서 내 번호 노출…밤낮 전화온다” 피해 호소 최근 글로벌 화제작으로 떠오른 국내 넷플릭스 드라마 ..‘오징어 게임’에 개인 휴대전화 번호가 노출되는 일이 발생했다... .. .. .. ..전화번호 노출 피해자 A 씨는 23일 머니투데이를 통해 ..“‘오징어 게임’ 방영 이후 일상생활이 어려울 정도로 24시간 문자와 전화가 쉴 새 없이 온다..',
#     'news_id': '01100401.20210923173629001',
#     'provider': '동아일보',
#     'provider_news_id': '20210923.109367664.2',
#     'published_at': '2021-09-23T00:00:00.000+09:00',
#     'title': '“‘오징어게임’서 내 번호 노출…밤낮 전화온다” 피해 호소'},
#    {'byline': '최가영',
#     'category': ['IT_과학>콘텐츠', 'IT_과학>모바일'],
#     'category_incident': [],
#     'dateline': '2021-09-24T14:14:02.000+09:00',
#     'enveloped_at': '2021-09-24T14:14:02.000+09:00',
#     'hilight': '한국인, 넷플릭스에 쓴 돈 역대 최대...장년층에 인기 지난달 글로벌 온라인동영상 서비스(OTT) 넷플릭스에 우리나라 사람들이 쓴 돈이 역대 최대치로 집계됐다. .. ..23일, 앱·리테일 분석 서비스 와이즈앱의 집계에 따르면 지난 8월 한 달간 만 20세 이..〈<b>오징어게임</b>〉 역시 한국 드라마 최초로 미국 넷플릭스 1위를 기록해 큰 인기를 끌고 있다. ..',
#     'news_id': '08100401.20210924141402002',
#     'provider': 'YTN',
#     'provider_news_id': '202109241413014347',
#     'published_at': '2021-09-24T00:00:00.000+09:00',
#     'title': '한국인, 넷플릭스에 쓴 돈 역대 최대...장년층에 인기'},
#    {'byline': '김소영',
#     'category': ['IT_과학>콘텐츠', 'IT_과학>모바일', 'IT_과학>보안'],
#     'category_incident': [],
#     'dateline': '2021-09-24T06:22:00.000+09:00',
#     'enveloped_at': '2021-09-24T15:35:19.000+09:00',
#     'hilight': '“끝자리만 다른데 전화 폭주”…‘<b>오징어게임</b>’ 번호 노출피해 또 배우 이정재 주연의 국내 넷플릭스 드라마 ..‘오징어 게임’에 개인 휴대전화 번호가 노출되는 일이 벌어져 논란인 가운데, 해당 번호와 비슷한 번호를 가진 사람도 피해를 호소하고 나섰다... .. .. .. ..누리꾼 A 씨는 23일 트위터를 통해 ..‘오징어 게임’ 전화번호 노출 피해 사실을..',
#     'news_id': '01100401.20210924153519001',
#     'provider': '동아일보',
#     'provider_news_id': '20210924.109382507.2',
#     'published_at': '2021-09-24T00:00:00.000+09:00',
#     'title': '“끝자리만 다른데 전화 폭주”…‘오징어게임’ 번호 노출피해 또'},
#    {'byline': '칼럼니스트 위근우',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': ['사고>산업사고>화재'],
#     'dateline': '2021-09-24T19:08:34.000+09:00',
#     'enveloped_at': '2021-09-24T16:06:36.000+09:00',
#     'hilight': '‘<<b>오징어게임</b>>이 별로인 99가지 이유’ 같은 리스티클 형식으로 풀어내는 게 더 나을 것 같은 작품이다.....<b>오징어게임</b>에서 중간의 다리를 가로지르는.. 이병헌이란 거물급 배우를 캐스팅한 프론트맨의 과거와 그가 <b>오징어게임</b>의 지휘관이 된 이유도 궁금하지 않다... <b>오징어게임</b> 우승자가 되어 각성한 기훈이 어떻게 이 거대한 조직과 싸워나갈지도 궁금하지 않다...',
#     'news_id': '01100101.20210924160636001',
#     'provider': '경향신문',
#     'provider_news_id': '202109241602005',
#     'published_at': '2021-09-24T00:00:00.000+09:00',
#     'title': '[위근우의 리플레이]중년 남성에 대한 연민에서만 일관적인, 마구잡이 서바이벌 ‘오징어게임’'},
#    {'byline': '최혜승 기자',
#     'category': ['IT_과학>콘텐츠', '문화>출판', '문화>방송_연예'],
#     'category_incident': [],
#     'dateline': '2021-09-24T20:34:02.000+09:00',
#     'enveloped_at': '2021-09-24T20:34:35.000+09:00',
#     'hilight': '필리핀서 ..“무궁화 꽃이 피었습니다”… 네티즌 ..‘<b>오징어게임</b>’ 인증샷 올려 필리핀 도심 한복판에서 ..“무궁화 꽃이 피었습니다”가 울려 퍼지고 있다... 넷플릭스가 자체 제작 드라마 ..‘<b>오징어게임</b>’을 홍보하기 위해 드라마에 등장하는 대형 술래 인형을 쇼핑몰 앞에 설치했기 때문이다... .. .. .. ..24일 필리핀매체 GM..‘<b>오징어게임</b>’에서 ..',
#     'news_id': '01100801.20210924203435001',
#     'provider': '조선일보',
#     'provider_news_id': '2021092401818',
#     'published_at': '2021-09-24T00:00:00.000+09:00',
#     'title': '필리핀서 “무궁화 꽃이 피었습니다”… 네티즌 ‘오징어게임’ 인증샷 올려'},
#    {'byline': '한성희 기자',
#     'category': ['IT_과학>콘텐츠', 'IT_과학>모바일', '사회>미디어'],
#     'category_incident': [],
#     'dateline': '2021-09-24T21:37:32.000+09:00',
#     'enveloped_at': '2021-09-24T20:40:12.000+09:00',
#     'hilight': '\'<b>오징어게임</b>\' 노출로 전화 폭주…"100만 원 보상하겠다" ..<앵커> .. .. .. .. .. ..최근 큰 인기를 끌고 있는 넷플릭스 드라마에서 아무 상관없는 사람의..\'<b>오징어게임</b>\'의 한 장면에 8자리 번호가 나온 뒤부터 그의 일상은 무너졌습니다...(빚이) 12억이 있으니 역전할 수 있도록 자기를 정말 도와달라고, <b>오징어게임</b>에 참여하고 싶다고.] ..',
#     'news_id': '08100301.20210924204012001',
#     'provider': 'SBS',
#     'provider_news_id': 'N1006475598',
#     'published_at': '2021-09-24T00:00:00.000+09:00',
#     'title': '\'오징어게임\' 노출로 전화 폭주…"100만 원 보상하겠다"'},
#    {'byline': '장구슬(jang.guseul@joongang.co.kr)',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-25T06:43:15.000+09:00',
#     'enveloped_at': '2021-09-24T22:03:55.000+09:00',
#     'hilight': "압도적 영희 로봇...이정재도 극찬한 ..'<b>오징어게임</b>' 세트장 비밀 신선한 소재로 전세계적으로 인기를 끌고 있는 넷플릭스 오리지널 드라마 ..‘오징어 게임’이 제작기 영상을 통해 세트장 설치 비하인드를 공개했다... .. .. .. .. 24일 넷플릭스는 ..‘오징어 게임’의 제작기 영상을 공개했다... ..‘오징어 게임’은 456억원의 상금이 걸린 의..",
#     'news_id': '01100901.20210924220355001',
#     'provider': '중앙일보',
#     'provider_news_id': '25009450',
#     'published_at': '2021-09-24T00:00:00.000+09:00',
#     'title': "압도적 영희 로봇...이정재도 극찬한 '오징어게임' 세트장 비밀"},
#    {'byline': '오원석(oh.wonseok@joongang.co.kr)',
#     'category': ['문화>방송_연예', 'IT_과학>콘텐츠', '문화>영화'],
#     'category_incident': [],
#     'dateline': '2021-09-25T06:43:22.000+09:00',
#     'enveloped_at': '2021-09-24T22:46:58.000+09:00',
#     'hilight': "'<b>오징어게임</b>' 푹 빠졌다 인생 ..'<b>오징어게임</b>'에 전 세계가 주목하고 있다... 달고나를 집에서도 만들어볼 수 있도록 국자와 별 등의 모양 틀, 뒤집개 등으로 이루어진 이 상품에는 <b>오징어게임</b> 드라마 로고가 포함돼 있다... <b>오징어게임</b> 2화에서는 ....<b>오징어게임</b>.. <b>오징어게임</b>이 묘사한 한국 내 외국인노동자 역할로 출연한 배우들에게도 조명이 비치고 있다...",
#     'news_id': '01100901.20210924224658001',
#     'provider': '중앙일보',
#     'provider_news_id': '25009453',
#     'published_at': '2021-09-24T00:00:00.000+09:00',
#     'title': "美이베이서 'Dalgona' 불티...전 세계 '오징어게임' 푹 빠졌다"},
#    {'byline': '오원석(oh.wonseok@joongang.co.kr)',
#     'category': ['문화>방송_연예', 'IT_과학>콘텐츠', 'IT_과학>모바일'],
#     'category_incident': [],
#     'dateline': '2021-09-25T06:43:32.000+09:00',
#     'enveloped_at': '2021-09-24T23:54:21.000+09:00',
#     'hilight': '\'<b>오징어게임</b>\' 전화번호 피해자…"100만원 주겠다더라" 미국에서 인기 순위 1위에 오르는 등 인기몰이 중인 넷플릭스 드라마 ..\'<b>오징어게임</b>\'이 전화번호 노출 사고로 논란을 빚고 있다... 드라마 안에서 누..\'<b>오징어게임</b>에 참가하고 싶다\'는 황당한 내용의 문자메시지까지 받았다며 고충을 토로했다...\'<b>오징어게임</b>\'의 초대장을 경찰에 신고하는 장면에서 나온다...',
#     'news_id': '01100901.20210924235421001',
#     'provider': '중앙일보',
#     'provider_news_id': '25009456',
#     'published_at': '2021-09-24T00:00:00.000+09:00',
#     'title': '\'오징어게임\' 전화번호 피해자…"100만원 주겠다더라"'},
#    {'byline': '이혜운 기자',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-25T00:21:20.000+09:00',
#     'enveloped_at': '2021-09-25T00:22:34.000+09:00',
#     'hilight': '‘<b>오징어게임</b>’, 전세계 넷플릭스 1위 올랐다..... 한국 드라마 최초 넷플릭스 오리지널 시리즈 ..‘오징어 게임’이 국내 드라마 최초로 전 세계 넷플릭스 1위를 차지했다... .. .. .. ..플릭스패트롤에 따르면, 지난 17일 공개된 넷플릭스 오리지널 시리즈 ..‘오징어 게임’은 24일(현지시각) 전체 순위 1위를 차지했다... 2위는 ..‘오티스..',
#     'news_id': '01100801.20210925002234001',
#     'provider': '조선일보',
#     'provider_news_id': '2021092500041',
#     'published_at': '2021-09-25T00:00:00.000+09:00',
#     'title': '‘오징어게임’, 전세계 넷플릭스 1위 올랐다... 한국 드라마 최초'},
#    {'byline': '이유나',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-25T08:02:02.000+09:00',
#     'enveloped_at': '2021-09-25T08:02:02.000+09:00',
#     'hilight': "[Y랭킹] 정호연→이유미, 美친 임팩트 ..'<b>오징어게임</b>' 신예 5人 넷플릭스 시리즈 ..'오징어 게임'이 화제인 가운데, 등장만으로도 어마어마한 임팩트를 선사한 ..'오징어 게임' 속 신인 배우들이 뜨거운 이슈로 자리매김 중이다. .. ..지난 17일 넷플릭스에서 공개된 ..'오징어 게임'은 21일(현지시간) 미국 넷플릭스를 비롯한 주요 국가들에서 전체..",
#     'news_id': '08100401.20210925080202002',
#     'provider': 'YTN',
#     'provider_news_id': '202109250800117632',
#     'published_at': '2021-09-25T00:00:00.000+09:00',
#     'title': "[Y랭킹] 정호연→이유미, 美친 임팩트 '오징어게임' 신예 5人"},
#    {'byline': '이해준(lee.hayjune@joongang.co.kr)',
#     'category': ['IT_과학>콘텐츠', 'IT_과학>모바일'],
#     'category_incident': [],
#     'dateline': '2021-09-25T20:50:15.000+09:00',
#     'enveloped_at': '2021-09-25T11:45:09.000+09:00',
#     'hilight': "'<b>오징어게임</b>' 신드롬 넷플릭스 오리지널 드라마 .. 린가드는 지난 22일에도<b>오징어게임</b>의 화면을 캡쳐해 게시했다...‘<b>오징어게임</b>’의 짧은 영상이 공유되고, 드라마에 대한 의견이 게시되고 있다...‘위챗’에서는 <b>오징어게임</b>이라는 해시태그가 만들어졌다...‘<b>오징어게임</b>’ 관련 상품이 속속 올라오고 있다.....<b>오징어게임</b>에 나온 주인공이 입었던 티셔츠는 39.95..",
#     'news_id': '01100901.20210925114509001',
#     'provider': '중앙일보',
#     'provider_news_id': '25009556',
#     'published_at': '2021-09-25T00:00:00.000+09:00',
#     'title': "30달러 달고나 세트까지 등장…전세계 '오징어게임' 신드롬"},
#    {'byline': '이은비',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-25T13:52:02.000+09:00',
#     'enveloped_at': '2021-09-25T13:52:02.000+09:00',
#     'hilight': "'오징어 게임' 한국 드라마 최초 전 세계 넷플릭스 1위 넷플릭스 오리지널 시리즈 ..'오징어 게임'(감독 황동혁)이 한국 드라마 최초로 전 세계 넷플릭스 1위를 차지했다. .. ..24일(현지 시간) 글로벌 온라인 동영상 서비스(OTT) 순위 집계 사이트 플릭스 패트롤에 따르면 <b>오징어게임</b>이 ..'넷플릭스 인기 TV 프로그램 톱10' 세계 1위로 올랐다..",
#     'news_id': '08100401.20210925135202001',
#     'provider': 'YTN',
#     'provider_news_id': '202109251350012465',
#     'published_at': '2021-09-25T00:00:00.000+09:00',
#     'title': "'오징어 게임' 한국 드라마 최초 전 세계 넷플릭스 1위"},
#    {'byline': '박태근',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-25T07:03:00.000+09:00',
#     'enveloped_at': '2021-09-25T16:10:22.000+09:00',
#     'hilight': '“요즘 핫한 <b>오징어게임</b> 보니, 정부·여당 생각이…” 국민의힘 대권주자인 원희룡 전 제주지사가 세계적으로 인기를 끌고 있는 넷플릭스 오리지널 시리즈 ..<b>오징어게임</b>(감독 황동혁)은 24일 ..<b>오징어게임</b>은 456억원의 상금이 걸린 의문의 서바이벌(생존) 게임에 참가한 사람들이 최후의 승자가 되기 위해 목숨을 걸고 극한의 게임에 도전하는 이야기를 담은 9회 분..',
#     'news_id': '01100401.20210925161022001',
#     'provider': '동아일보',
#     'provider_news_id': '20210925.109411175.2',
#     'published_at': '2021-09-25T00:00:00.000+09:00',
#     'title': '원희룡 “요즘 핫한 오징어게임 보니, 정부·여당 생각이…”'},
#    {'byline': '오원석(oh.wonseok@joongang.co.kr)',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-26T06:45:54.000+09:00',
#     'enveloped_at': '2021-09-25T23:04:10.000+09:00',
#     'hilight': "이태원역 ..'오징어 게임' 팝업 세트장 조기 철거한다…왜 넷플릭스에서 공개된 한국 드라마로 전 세계적인 인기를 끌고 있는 ..'<b>오징어게임</b>'이 이번엔 ..'방역논란'에 휩싸였다... 드라마 홍보를 위해 서울 지하철 6호선 이태원역에 세트장을 마련했는..'<b>오징어게임</b>' 체험공간 ..'<b>오징어게임</b>'에 등장한 세트를 꾸며 놓은 공간으로 이달 초부터 운영돼 왔다...",
#     'news_id': '01100901.20210925230410001',
#     'provider': '중앙일보',
#     'provider_news_id': '25009600',
#     'published_at': '2021-09-25T00:00:00.000+09:00',
#     'title': "이태원역 '오징어 게임' 팝업 세트장 조기 철거한다…왜"},
#    {'byline': '정희윤(chung.heeyun@joongang.co.kr)',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-26T17:01:45.000+09:00',
#     'enveloped_at': '2021-09-26T16:57:33.000+09:00',
#     'hilight': "확진자 3000명에도 북적…'<b>오징어게임</b>'에 마비된 이태원역 26일 오후 1시 서울 지하철 6호선 이태원역... 넷플릭스 드라마 ..‘오징어 게임’을 홍보하기 위해 이태원역에 만든 세트장인 ..‘오겜월드’를 찾은 시민들의 아쉬운 발걸음이 이어졌다... .. .. .. .. 이날 2시간이 걸려 충북 음성에서 서울로 올라왔다는 말레이시아인 시다(28)씨는 ..",
#     'news_id': '01100901.20210926165733001',
#     'provider': '중앙일보',
#     'provider_news_id': '25009701',
#     'published_at': '2021-09-26T00:00:00.000+09:00',
#     'title': "확진자 3000명에도 북적…'오징어게임'에 마비된 이태원역"},
#    {'byline': '고석현(ko.sukhyun@joongang.co.kr)',
#     'category': ['IT_과학>콘텐츠', 'IT_과학>모바일'],
#     'category_incident': [],
#     'dateline': '2021-09-27T06:27:50.000+09:00',
#     'enveloped_at': '2021-09-26T22:47:04.000+09:00',
#     'hilight': '..<b>오징어게임</b> 노출피해 번호, 제가 1억에 사겠습니다" 대선출마를 선언한 허경영 국가혁명당 명예대표는 넷플릭..\'<b>오징어게임</b>\'의 휴대폰번호 노출 사고 논란에 대해 .."\'<b>오징어게임</b>\'의 명함 속 노출된 전화번호의 주인께서 심각한 장난전화 피해를 받으신다고 들었다"며 ..\'<b>오징어게임</b>에 참가하고 싶다\'는 황당한 내용의 문자메시지까지 받았다"고 고충을 토로했다...',
#     'news_id': '01100901.20210926224704001',
#     'provider': '중앙일보',
#     'provider_news_id': '25009756',
#     'published_at': '2021-09-26T00:00:00.000+09:00',
#     'title': '허경영 "오징어게임 노출피해 번호, 제가 1억에 사겠습니다"'},
#    {'byline': '김명일 기자',
#     'category': ['IT_과학>콘텐츠', '정치>정치일반'],
#     'category_incident': [],
#     'dateline': '2021-09-26T23:52:28.000+09:00',
#     'enveloped_at': '2021-09-26T23:53:33.000+09:00',
#     'hilight': '“<b>오징어게임</b>에 노출된 폰 번호 1억에 사겠다” 허경영 국가혁명당 명예대표는 넷플릭스에서 공개된 한국 드라마 ..‘<b>오징어게임</b>’에 개인 휴대폰 번호가 노출된 것과 관련 ....<b>오징어게임</b>의 명함 속..“<b>오징어게임</b> 방영 이후 일상생활이 어려울 정도로 24시간 문자와 전화가 쉴 새 없이 온다...‘<b>오징어게임</b>에 네 번호가 나온다’고 얘기를 해줘 알았다”라고 했다...',
#     'news_id': '01100801.20210926235333001',
#     'provider': '조선일보',
#     'provider_news_id': '2021092601273',
#     'published_at': '2021-09-26T00:00:00.000+09:00',
#     'title': '허경영 “오징어게임에 노출된 폰 번호 1억에 사겠다”'},
#    {'byline': '고석현(ko.sukhyun@joongang.co.kr)',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-27T06:32:54.000+09:00',
#     'enveloped_at': '2021-09-27T01:05:38.000+09:00',
#     'hilight': '"내가 딱 이정재 그꼴" <b>오징어게임</b> 본 자영업자들 울분 왜 .."K-방역이야말로 현실판 ..\'<b>오징어게임</b>\'이다... ..\'<b>오징어게임</b>\' 시청 소감을 이같이 밝혔다...\'<b>오징어게임</b>\'은 사업실패·도박 등의 이유로 큰 빚을 진 사람들이 456억원의 상금을 받기 위해 목숨을 걸고 게임에 참여하는 내용을 담고있다...\'방역\'이라는 이름의 <b>오징어게임</b> 참가자들"이라며 ..',
#     'news_id': '01100901.20210927010538001',
#     'provider': '중앙일보',
#     'provider_news_id': '25009871',
#     'published_at': '2021-09-27T00:00:00.000+09:00',
#     'title': '"내가 딱 이정재 그꼴" 오징어게임 본 자영업자들 울분 왜'},
#    {'byline': '고석현(ko.sukhyun@joongang.co.kr)',
#     'category': ['IT_과학>콘텐츠', 'IT_과학>모바일', 'IT_과학>보안'],
#     'category_incident': [],
#     'dateline': '2021-09-27T06:32:56.000+09:00',
#     'enveloped_at': '2021-09-27T01:28:03.000+09:00',
#     'hilight': '\'<b>오징어게임</b>\'의 휴대폰번호 노출 사고 논란을 언급하며 .."\'<b>오징어게임</b>\'의 명함 속 노출된 전화번호의 주인께서 심각한 장난전화 피해를 받으신다고 들었다"며 ....<b>오징어게임</b>\' 안에선 8자리 전화번호가 공개됐는데, 휴대전화에서 이 8자리 번호를 입력하고 통화 버튼을..\'<b>오징어게임</b>에 참가하고 싶다\'는 황당한 내용의 문자메시지까지 받았다"고 고충을 토로했다...',
#     'news_id': '01100901.20210927012803001',
#     'provider': '중앙일보',
#     'provider_news_id': '25009872',
#     'published_at': '2021-09-27T00:00:00.000+09:00',
#     'title': '\'오징어\' 번호 1억에 산다던 허경영, 본인 번호 깠다 "룰 간단"'},
#    {'byline': '손효주',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-26T18:00:00.000+09:00',
#     'enveloped_at': '2021-09-27T03:03:23.000+09:00',
#     'hilight': '‘<b>오징어게임</b>’…달고나 만들고, 딱지치기 ..‘<b>오징어게임</b>’이 주말 내내 전 세계를 휩쓸며 ..<b>오징어게임</b>은 넷플릭스를 넘어 현실 세계와 타 플랫폼에서도 맹위를 떨치고 있다... 동영상 소셜미디어 틱톡엔 <b>오징어게임</b>에 나오는 지하철 승강장 내 딱지치기 장면이나 ....<b>오징어게임</b>에 등..넷플릭스가 서비스를 제공하지 않는 중국에서도 <b>오징어게임</b>의 반응은 폭발적이다...',
#     'news_id': '01100401.20210927030323001',
#     'provider': '동아일보',
#     'provider_news_id': '20210927.109425791.1',
#     'published_at': '2021-09-27T00:00:00.000+09:00',
#     'title': '세계인 게임 된 ‘오징어게임’…달고나 만들고, 딱지치기 ‘인증샷’'},
#    {'byline': '손효림 문화부 차장',
#     'category': ['문화>방송_연예', 'IT_과학>콘텐츠', '문화>출판'],
#     'category_incident': [],
#     'dateline': '2021-09-26T18:00:00.000+09:00',
#     'enveloped_at': '2021-09-27T03:05:05.000+09:00',
#     'hilight': '[광화문에서/손효림]절망 사회 비춘 ..‘<b>오징어게임</b>’, 현실은 과연 이보다 나은가 영화 ..‘보이스’에 나오는 보이스피싱 수법은 다양하다... 공사장에서 사고가 나 합의금이 필요하다며 현장 작업반장인 서준(변요한)의 아내에게 7000만 원을 송금하게 만들고, 대기업 지원자..‘<b>오징어게임</b>’까지...‘<b>오징어게임</b>’에서 참가자들을 죽음으로 내몬 것도 돈이었다...',
#     'news_id': '01100401.20210927030505001',
#     'provider': '동아일보',
#     'provider_news_id': '20210927.109425226.1',
#     'published_at': '2021-09-27T00:00:00.000+09:00',
#     'title': '[광화문에서/손효림]절망 사회 비춘 ‘오징어게임’, 현실은 과연 이보다 나은가'},
#    {'byline': '이혜운 기자',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-27T03:00:02.000+09:00',
#     'enveloped_at': '2021-09-27T03:10:31.000+09:00',
#     'hilight': '넷플릭스 창업자도 ..‘초록 운동복’ 입었다… <b>오징어게임</b> 신드롬 지난 17일 첫 공개 이후 넷플릭스 오리지널 시리즈 ..‘오징어 게임’의 순위는 10일째 내려간 적이 없다... .. .. .. 뚝! 저는 이제 죽는 건가요?”(<b>오징어게임</b> 달고나 틱톡 영상) ..“<b>오징어게임</b>에서 마지막에 살아남는 사람이 받는 계좌는 카카오뱅크 진짜 계좌”라는 글도 올라왔다...',
#     'news_id': '01100801.20210927031031001',
#     'provider': '조선일보',
#     'provider_news_id': '2021092700269',
#     'published_at': '2021-09-27T00:00:00.000+09:00',
#     'title': '넷플릭스 창업자도 ‘초록 운동복’ 입었다… 오징어게임 신드롬'},
#    {'byline': '',
#     'category': ['국제>국제일반', 'IT_과학>콘텐츠', 'IT_과학>모바일'],
#     'category_incident': ['범죄>범죄일반>방화'],
#     'dateline': '2021-09-27T11:53:02.000+09:00',
#     'enveloped_at': '2021-09-27T07:07:45.000+09:00',
#     'hilight': "흔들리는 가상자산 시장‥'<b>오징어게임</b>' 흥행질주 ..◀ 앵커 ..▶ .. ..파산설에 휩싸인 헝다에 이어 모든 가상자산을 불법 금융활동으로 규정한 중국 정부의 조치까지 중국발 이슈가 연일 세계 금융시장을 흔들고 있는데요. .. ..미국에서 바라보는 시각은 어떤지 실리콘밸리 현지 언론인 연결해보겠습니다. .. ..손재권 대표님 안녕하십니까? .. ..◀ 손..",
#     'news_id': '08100201.20210927070745001',
#     'provider': 'MBC',
#     'provider_news_id': '6303084',
#     'published_at': '2021-09-27T00:00:00.000+09:00',
#     'title': "흔들리는 가상자산 시장‥'오징어게임' 흥행질주"},
#    {'byline': '김수산 리포터',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-27T11:53:03.000+09:00',
#     'enveloped_at': '2021-09-27T07:48:20.000+09:00',
#     'hilight': '[이슈톡] 해외서도 열풍‥\'<b>오징어게임</b>\' 굿즈 인기 투데이 이슈톡입니다. .. ..넷플릭스 오리지널 드라마 ..\'오징어 게임\'이 세계적인 인기를 끌자, 드라마 속 다양한 제품들까지 주목을 받고 있다는데요... .. .. ..첫 번째 키워드는 .."해외서도 인기 ..\'오징어 게임\' 굿즈"입니다. .. ..무궁화 꽃이 피었습니다. .. ..구슬치기, 줄다리기..',
#     'news_id': '08100201.20210927074820003',
#     'provider': 'MBC',
#     'provider_news_id': '6303089',
#     'published_at': '2021-09-27T00:00:00.000+09:00',
#     'title': "[이슈톡] 해외서도 열풍‥'오징어게임' 굿즈 인기"},
#    {'byline': '김성현',
#     'category': ['IT_과학>콘텐츠', 'IT_과학>모바일'],
#     'category_incident': [],
#     'dateline': '2021-09-27T09:50:05.000+09:00',
#     'enveloped_at': '2021-09-27T09:50:05.000+09:00',
#     'hilight': '[Y이슈] 허경영 .."\'<b>오징어게임</b>\' 노출 피해 전화번호, 1억에 사겠다" 전세계적인 인기를 끌고 있는 넷플릭스 오리지널 시리즈 ..\'오징어 게임\'에 개인 휴대전화 번호가 노출된 피해자가 고통을 호소하.."\'<b>오징어게임</b>\'의 명함 속 노출된 전화번호의 주인께서 심각한 장난전화 피해를 받으신다고 들었다"며 해당 전화번호를 자신이 1억 원에 사겠다고 제안했다...',
#     'news_id': '08100401.20210927095005001',
#     'provider': 'YTN',
#     'provider_news_id': '202109270949525659',
#     'published_at': '2021-09-27T00:00:00.000+09:00',
#     'title': '[Y이슈] 허경영 "\'오징어게임\' 노출 피해 전화번호, 1억에 사겠다"'},
#    {'byline': '강내리',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-27T10:16:03.000+09:00',
#     'enveloped_at': '2021-09-27T10:16:03.000+09:00',
#     'hilight': "정호연, 알고보니 제니와 절친…'<b>오징어게임</b>' 촬영장 투샷 공개 배우 정호연과 걸그룹 ..'<b>오징어게임</b>' 촬영장을 찾은 것으로 보이는 제니와 나란히 앉아 다정한 포즈를 취했다. ..'<b>오징어게임</b>'을 통해 첫 연기에 도전한 정호연을 위해 촬영장에 커피차를 선물하는 등 응원을 아끼지 않은 것으로 전해졌다...'<b>오징어게임</b>'에서 탈북자 강새벽 역을 맡아 열연했다...",
#     'news_id': '08100401.20210927101603001',
#     'provider': 'YTN',
#     'provider_news_id': '202109271014250602',
#     'published_at': '2021-09-27T00:00:00.000+09:00',
#     'title': "정호연, 알고보니 제니와 절친…'오징어게임' 촬영장 투샷 공개"},
#    {'byline': '이유나',
#     'category': ['IT_과학>콘텐츠', 'IT_과학>모바일'],
#     'category_incident': [],
#     'dateline': '2021-09-27T10:36:02.000+09:00',
#     'enveloped_at': '2021-09-27T10:36:02.000+09:00',
#     'hilight': '[Y초점] 美보그, ..\'<b>오징어게임</b>\' 정호연 인기 편승..."또 초대하면 되잖아" 미국 보그 유튜브 채널이 정호연이 출연하는 4년 전 영상 제목에 ..\'오징어 게임\'을 넣어 수정하면서 알고리즘의 수혜를 톡톡히 보고 있다. .. ..최근 구독자수 1040만 명에 달하는 미국 보그 유튜브 채널은 지난 2016년 10월 게재한 ..\'정호연의 퍼펙트 스킨과 투..',
#     'news_id': '08100401.20210927103602002',
#     'provider': 'YTN',
#     'provider_news_id': '202109271034056449',
#     'published_at': '2021-09-27T00:00:00.000+09:00',
#     'title': '[Y초점] 美보그, \'오징어게임\' 정호연 인기 편승..."또 초대하면 되잖아"'},
#    {'byline': '정윤주',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-27T11:46:03.000+09:00',
#     'enveloped_at': '2021-09-27T11:46:03.000+09:00',
#     'hilight': '허경영 .."오징어 게임에 노출된 번호, 내가 1억 원에 사겠다" 허경영 국가혁명당 명예대표가 넷플릭스 드라마 ..\'오징어 게임\'에 노출된 개인 휴대폰 번호를 1억 원에 사겠다고 밝혔다. .. ..허 대표는 26일 자신의 페이스북에서 .."오징어 게임 명함 속 .."<b>오징어게임</b> 방영 이후 일상생활이 어려울 정도로 24시간 문자와 전화가 쉴 새 없이 온다...',
#     'news_id': '08100401.20210927114603001',
#     'provider': 'YTN',
#     'provider_news_id': '202109271145020490',
#     'published_at': '2021-09-27T00:00:00.000+09:00',
#     'title': '허경영 "오징어 게임에 노출된 번호, 내가 1억 원에 사겠다"'},
#    {'byline': '이은지',
#     'category': ['IT_과학>콘텐츠', '문화>방송_연예', '문화>영화'],
#     'category_incident': [],
#     'dateline': '2021-09-28T13:08:03.000+09:00',
#     'enveloped_at': '2021-09-27T12:28:02.000+09:00',
#     'hilight': '"성기훈은 왜 456번이었을까" <b>오징어게임</b> 시즌2는 언제? ..[관련 동영상 보기] .. .. .. .. ..YTN라디오(FM 94.5) ..[YTN 뉴스FM 슬기로운 라디오생활] .. ..□ 방송일시 ..: 2021년 9월 27일 .. 말씀하신 것처럼 <b>오징어게임</b>은 동네에서 함께하던 놀이 중 하나잖아요... N사에 <b>오징어게임</b>이 있었다면, WV사에는 ..',
#     'news_id': '08100401.20210927122802001',
#     'provider': 'YTN',
#     'provider_news_id': '202109271220491348',
#     'published_at': '2021-09-27T00:00:00.000+09:00',
#     'title': '"성기훈은 왜 456번이었을까" 오징어게임 시즌2는 언제?'},
#    {'byline': '장구슬(jang.guseul@joongang.co.kr)',
#     'category': ['IT_과학>콘텐츠', 'IT_과학>모바일'],
#     'category_incident': [],
#     'dateline': '2021-09-27T14:20:33.000+09:00',
#     'enveloped_at': '2021-09-27T13:17:10.000+09:00',
#     'hilight': '폰 번호 이어 456억 계좌 유출…<b>오징어게임</b> 측 .."사전 협조" 전 세계적으로 인기를 끌고 있는 넷플릭스 오리지널 드라마 ..‘오징어 게임’ 측이 작품 속 계좌번호 유출 의혹에 대해 ..“제작 과정에서 사전 협조 이후 사용한 번호”라고 밝혔다... .. .. .. .. ..‘오징어 게임’의 유통 및 방송사인 넷플릭스 측은 27일 뉴스1에 ..“극 중 ..',
#     'news_id': '01100901.20210927131710001',
#     'provider': '중앙일보',
#     'provider_news_id': '25009992',
#     'published_at': '2021-09-27T00:00:00.000+09:00',
#     'title': '폰 번호 이어 456억 계좌 유출…오징어게임 측 "사전 협조"'},
#    {'byline': '하수영(ha.suyoung@joongang.co.kr)',
#     'category': ['정치>정치일반', 'IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-27T15:56:25.000+09:00',
#     'enveloped_at': '2021-09-27T14:32:04.000+09:00',
#     'hilight': '"아빠가 곽상도 아니라 미안"…\'오십억게임\' 패러디 쏟아졌다 곽상도 무소속 의원(62)의 아들 곽병채(32) 씨가 ..‘<b>오징어게임</b>’을 패러디한 .. <b>오징어게임</b> 포스터의 제목 부분만 ..‘오십억게임’으로 바꾼 이미지부터 시작해 <b>오징어게임</b>의 주인공인 배우 이정재를 곽상도 의원으로 바꿔놓은 이미지까지 다양하다...“나는 너무나 치밀하게 설계된 <b>오징어게임</b> 속 ..',
#     'news_id': '01100901.20210927143204001',
#     'provider': '중앙일보',
#     'provider_news_id': '25010012',
#     'published_at': '2021-09-27T00:00:00.000+09:00',
#     'title': '"아빠가 곽상도 아니라 미안"…\'오십억게임\' 패러디 쏟아졌다'},
#    {'byline': '김소정 기자',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-27T15:30:30.000+09:00',
#     'enveloped_at': '2021-09-27T15:31:48.000+09:00',
#     'hilight': '‘<b>오징어게임</b>’ 출연 제의를 받은 적 있는 미국인 유튜버가 뒤늦게 아쉬움을 토로했다...“<b>오징어게임</b>이 지금 전세계 1등을 달리고 있다... 저희 엄마를 비롯해 사촌들이 전부 <b>오징어게임</b>을 봤다... 그런데 저는 <b>오징어게임</b> 때문에 화가 난다”고 했다.....<b>오징어게임</b>’ 출연 제의.. 그때 출연을 거절한 작품이 지금 1위를 달리고 있는 <b>오징어게임</b>”이라고 했다...',
#     'news_id': '01100801.20210927153148001',
#     'provider': '조선일보',
#     'provider_news_id': '2021092701317',
#     'published_at': '2021-09-27T00:00:00.000+09:00',
#     'title': '“속옷만 입으라 해서…” 오징어게임 출연 거절한 유튜버, 뒤늦은 후회'},
#    {'byline': '정채빈 기자',
#     'category': ['IT_과학>콘텐츠', 'IT_과학>모바일'],
#     'category_incident': [],
#     'dateline': '2021-09-27T15:36:33.000+09:00',
#     'enveloped_at': '2021-09-27T15:38:15.000+09:00',
#     'hilight': '넷플릭스 ..“<b>오징어게임</b> 속 실제 계좌번호, 사전 협조 후 사용한 것” 넷플릭스 드라마 ..‘오징어 게임’ 속 계좌번호가 실제 계좌인 것으로 드러나 논란이 커지고 있는 가운데, 넷플릭스 측이 관련 입장을 밝혔다... .. .. .. ..27일 넷플릭스 측은 조선닷컴에 ..“콘텐츠.. 그는 <b>오징어게임</b> 속 계좌번호로 송금을 시도하는 방식으로 이를 확인했다...',
#     'news_id': '01100801.20210927153815001',
#     'provider': '조선일보',
#     'provider_news_id': '2021092701334',
#     'published_at': '2021-09-27T00:00:00.000+09:00',
#     'title': '넷플릭스 “오징어게임 속 실제 계좌번호, 사전 협조 후 사용한 것”'},
#    {'byline': '김명일 기자',
#     'category': ['IT_과학>콘텐츠', '정치>정치일반'],
#     'category_incident': ['사회>사회갈등>시위'],
#     'dateline': '2021-09-27T16:41:02.000+09:00',
#     'enveloped_at': '2021-09-27T16:41:58.000+09:00',
#     'hilight': '“증세·집값 못 버티면 탈락” <b>오징어게임</b> 따라한 文게임 나왔다 넷플릭스에서 공개된 한국 드라마 ..‘<b>오징어게임</b>’이 큰 인기를 끌면서 온라인상에서는 이를 패러디한 정치 풍자 게시글이 잇따라 등장하고 있다...‘<b>오징어게임</b>’을 패러디한 ..문재인 정부에서 시행된 각종 정책이 <b>오징어게임</b>만큼 국민들을 힘들게 한다고 풍자한 것이다.....<b>오징어게임</b>에서 참가자들에게..',
#     'news_id': '01100801.20210927164158001',
#     'provider': '조선일보',
#     'provider_news_id': '2021092701446',
#     'published_at': '2021-09-27T00:00:00.000+09:00',
#     'title': '“증세·집값 못 버티면 탈락” 오징어게임 따라한 文게임 나왔다'},
#    {'byline': '김소영',
#     'category': ['IT_과학>콘텐츠', 'IT_과학>보안', 'IT_과학>모바일'],
#     'category_incident': [],
#     'dateline': '2021-09-27T07:21:00.000+09:00',
#     'enveloped_at': '2021-09-27T16:42:47.000+09:00',
#     'hilight': '‘<b>오징어게임</b>’ 계좌번호도 유출?…넷플릭스 ..“사전 협조받았다” 개인 전화번호 노출로 한차례 구설에 올랐던 넷플릭스 오리지널 콘텐츠 ..‘오징어 게임’이 이번엔 계좌번호 유출 논란에 휩싸인 가운데, 넷플릭스 측이 입장을 밝혔다... .. .. .. ..넷플릭스는 27일 ..“‘오징어 게임’에 등장하는 계좌번호는 제작 단계부터 사용 가능하도록 협조가 된 ..',
#     'news_id': '01100401.20210927164247001',
#     'provider': '동아일보',
#     'provider_news_id': '20210927.109439181.2',
#     'published_at': '2021-09-27T00:00:00.000+09:00',
#     'title': '‘오징어게임’ 계좌번호도 유출?…넷플릭스 “사전 협조받았다”'},
#    {'byline': '하수영(ha.suyoung@joongang.co.kr)',
#     'category': ['IT_과학>콘텐츠', '정치>청와대'],
#     'category_incident': [],
#     'dateline': '2021-09-27T18:00:21.000+09:00',
#     'enveloped_at': '2021-09-27T17:51:29.000+09:00',
#     'hilight': "“다주택‧자영업자는 탈락”…초록 추리닝 ..'문재인 게임' 등장 넷플릭스 인기드라마 ..‘<b>오징어게임</b>’ 패러디가 인기를 끌고 있는 가운데, 문재인 대통령을 풍자, 비판하기 위한 패러디인 .. 문재인 대통령이 <b>오징어게임</b>의 상징적인 의상인 청록색 운동복을 입고 있는 모습이 담긴 포스터와 문재인게임에서 생존하는 방법이 적힌 게시물이 온라인상에서 확산하고 있다...",
#     'news_id': '01100901.20210927175129001',
#     'provider': '중앙일보',
#     'provider_news_id': '25010064',
#     'published_at': '2021-09-27T00:00:00.000+09:00',
#     'title': "“다주택‧자영업자는 탈락”…초록 추리닝 '문재인 게임' 등장"},
#    {'byline': '남지은 기자',
#     'category': ['IT_과학>콘텐츠', 'IT_과학>모바일', 'IT_과학>보안'],
#     'category_incident': [],
#     'dateline': '2021-09-28T02:40:02.000+09:00',
#     'enveloped_at': '2021-09-27T18:29:54.000+09:00',
#     'hilight': '‘<b>오징어게임</b>’ 속 피해번호…지울 ..‘노력’은 안해봤나요 넷플릭스 드라마 ..<오징어 게임>에서 노출된 전화번호 때문에 큰 피해를 보고 있다는 주장이 이어지며 문제가 되고 있다... 노출된 전화번호와 같은 번호나 비슷한 번호를 쓰는 피해자들의 문제제기가 시작된 지 며칠이 지났지만, 넷플릭스 쪽은 27일 오전까지 이 번호를 고스란히 노출한 채 방영하고 있..',
#     'news_id': '01101001.20210927182954002',
#     'provider': '한겨레',
#     'provider_news_id': '1012920',
#     'published_at': '2021-09-27T00:00:00.000+09:00',
#     'title': '‘오징어게임’ 속 피해번호…지울 ‘노력’은 안해봤나요'},
#    {'byline': '이보람(lee.boram2@joongang.co.kr)',
#     'category': ['IT_과학>콘텐츠', '문화>방송_연예', '문화>영화'],
#     'category_incident': [],
#     'dateline': '2021-09-28T06:26:36.000+09:00',
#     'enveloped_at': '2021-09-27T18:52:43.000+09:00',
#     'hilight': "'<b>오징어게임</b>' 이 배역 전 세계적인 인기를 끌고 있는 넷플릭스 오리지널 시리즈 ..‘<b>오징어게임</b>’의 출연 제안을 거절했던 한 유튜버가 <b>오징어게임</b> 흥행에 아쉬움을 토로했다...“<b>오징어게임</b> 출연기회 날리고 후회하는 아내와 달고나 만들기”라는 영상이 올라왔다...“제가 그때 촬영 거절한 작품이 지금 1위를 달리고 있는 <b>오징어게임</b>이다.....<b>오징어게임</b>은 넷플릭스..",
#     'news_id': '01100901.20210927185243001',
#     'provider': '중앙일보',
#     'provider_news_id': '25010079',
#     'published_at': '2021-09-27T00:00:00.000+09:00',
#     'title': '"속옷 입고 500만원"…유튜버가 거절한 \'오징어게임\' 이 배역'},
#    {'byline': '오원석(oh.wonseok@joongang.co.kr)',
#     'category': ['문화>방송_연예', 'IT_과학>콘텐츠', '문화>요리_여행'],
#     'category_incident': [],
#     'dateline': '2021-09-28T06:26:44.000+09:00',
#     'enveloped_at': '2021-09-27T19:09:18.000+09:00',
#     'hilight': "'<b>오징어게임</b>' 공포의 영희, 어디있나 했더니…박물관에 보관 넷플릭스에서 전 세계적인 인기몰이 중인 드라마 ..'<b>오징어게임</b>'의 ..'영희 인형'은 현재 충북 진천의 한 박물관에 보관중인 것으로 27일 확인됐다... 다..'<b>오징어게임</b>'의 첫 번째 놀이인 ..'<b>오징어게임</b>'은 참가자 456명이 우승 상금 456억원을 걸고 생존 게임을 벌이는 내용을 담고 있다...",
#     'news_id': '01100901.20210927190918001',
#     'provider': '중앙일보',
#     'provider_news_id': '25010084',
#     'published_at': '2021-09-27T00:00:00.000+09:00',
#     'title': "'오징어게임' 공포의 영희, 어디있나 했더니…박물관에 보관"},
#    {'byline': '이보람(lee.boram2@joongang.co.kr)',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-28T06:26:45.000+09:00',
#     'enveloped_at': '2021-09-27T19:25:53.000+09:00',
#     'hilight': '블핑 제니, <b>오징어게임</b> 촬영장 갔었다…‘67번’ 정호연 응원 블랙핑크의 제니가 넷플릭스 오리지널 시리즈 ..‘<b>오징어게임</b>’ 촬영장을 방문했던 모습을 담은 사진이 공개됐다... 두 사람은 <b>오징어게임</b> 세트장을 배경으로 포즈를 취하고 있다... 특히 제니는 <b>오징어게임</b>으로 처음 연기에 도전하는 정호연을 응원하기 위해 촬영장 방문 당시 커피차를 선물하기도 했다...',
#     'news_id': '01100901.20210927192553001',
#     'provider': '중앙일보',
#     'provider_news_id': '25010085',
#     'published_at': '2021-09-27T00:00:00.000+09:00',
#     'title': '블핑 제니, 오징어게임 촬영장 갔었다…‘67번’ 정호연 응원'},
#    {'byline': '이보람(lee.boram2@joongang.co.kr)',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-28T06:27:42.000+09:00',
#     'enveloped_at': '2021-09-27T23:05:09.000+09:00',
#     'hilight': '‘<b>오징어게임</b>’이 전 세계적인 인기를 끌고 있지만 어린아이를 둔 부모나 아이들을 가르치는 교사 등 몇몇 어른들은 <b>오징어게임</b> 열풍이 반갑지만은 않다...“5학년 수업하는 데 애들 <b>오징어게임</b> 얘기밖에 안 하더라.....<b>오징어게임</b> 얘기밖에.. 하지만 <b>오징어게임</b> 인기가 치솟자 유튜브나 짧은 동영상을 서비스하는 틱톡에서 작품 리뷰 등 관련 콘텐트가 넘쳐나고 있다...',
#     'news_id': '01100901.20210927230509001',
#     'provider': '중앙일보',
#     'provider_news_id': '25010111',
#     'published_at': '2021-09-27T00:00:00.000+09:00',
#     'title': '"무궁화꽃 하면 총쏴 사람 죽어요" 6살 아이에 기겁했다'},
#    {'byline': '박민우',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-27T18:00:00.000+09:00',
#     'enveloped_at': '2021-09-28T03:03:35.000+09:00',
#     'hilight': '“고맙다, <b>오징어게임</b>”… K콘텐츠, 주식시장서 신바람 넷플릭스 오리지널 시리즈 ..‘<b>오징어게임</b>’이 전 세계적으로 흥행 돌풍을 일으키면서 국내 주식 시장에서 .. 쇼박스는 <b>오징어게임</b>의 제작사인 싸이런픽쳐스에 10억 원을 투자해 <b>오징어게임</b> 테마주로 분류된다... <b>오징어게임</b>은 한국 드라마 최초로 전 세계 넷플릭스 드라마 부문 1위를 사흘 연속 이어갔다...',
#     'news_id': '01100401.20210928030335001',
#     'provider': '동아일보',
#     'provider_news_id': '20210928.109442127.1',
#     'published_at': '2021-09-28T00:00:00.000+09:00',
#     'title': '“고맙다, 오징어게임”… K콘텐츠, 주식시장서 신바람'},
#    {'byline': '이해인 기자\n이해인 기자  채제우 기자',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': ['사고>산업사고>폭발', '사고>산업사고>화재'],
#     'dateline': '2021-09-28T04:54:19.000+09:00',
#     'enveloped_at': '2021-09-28T04:55:01.000+09:00',
#     'hilight': '“이번 게임은 집값 올리기, 못버티는 무주택자는 탈락” ..“다음 게임은 거리두기, 못버티는 자영업자는 탈락” ..‘첫 번째 게임은 증세(增稅)입니다... 버티지 못하는 다주택자는 탈락입니다... 두 번째 게임은 집값 올리기입니다... 버티지 못하는 무주택자는 탈락입니다... 세..“지금 자영업자들의 현실이 <b>오징어게임</b> 참가자들의 모습과 똑같다”고 했다...',
#     'news_id': '01100801.20210928045501001',
#     'provider': '조선일보',
#     'provider_news_id': '2021092800307',
#     'published_at': '2021-09-28T00:00:00.000+09:00',
#     'title': '“이번 게임은 집값 올리기, 못버티는 무주택자는 탈락” “다음 게임은 거리두기, 못버티는 자영업자는 탈락”'},
#    {'byline': '이유나',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-28T09:56:05.000+09:00',
#     'enveloped_at': '2021-09-28T09:56:05.000+09:00',
#     'hilight': '넷플릭스 CEO .."韓 ..\'<b>오징어게임</b>\', 넷플릭스의 가장 큰 작품 될 수도" 테드 서랜도스(Ted Sarandos) 넷플릭스 공동 최고 경영 책임자(CEO) 겸 최고 콘텐츠 책임자(CCO)가 한국 넷플릭스 시리즈 ..\'오징어 게임\'의 인기를 언급했다. .. ..현지 시간으로 27일 미국에서 열린 ..\'코드 컨퍼런스(Code Conference) 20..',
#     'news_id': '08100401.20210928095605001',
#     'provider': 'YTN',
#     'provider_news_id': '202109280955557912',
#     'published_at': '2021-09-28T00:00:00.000+09:00',
#     'title': '넷플릭스 CEO "韓 \'오징어게임\', 넷플릭스의 가장 큰 작품 될 수도"'},
#    {'byline': '온라인뉴스팀',
#     'category': ['IT_과학>콘텐츠', '문화>방송_연예', '문화>영화'],
#     'category_incident': [],
#     'dateline': '2021-09-28T00:39:00.000+09:00',
#     'enveloped_at': '2021-09-28T09:59:41.000+09:00',
#     'hilight': '3일에 500만원…‘<b>오징어게임</b>’ 출연 거절한 외국인 ..“후회” 한 유튜버가 세계적으로 흥행한 넷플릭스 시리즈 ..‘오징어 게임’의 출연 제안을 거절했던 사연을 공개하며 아쉬움을 토로했다... .. .. .. ..한국 남성과 결혼 후 한국에서 유튜버로 활동하고 있는 외국인 여성 레이는 26일 자신의 채널 ..‘레이진’에서 ..“한국에 거주하고 있는 외국..',
#     'news_id': '01100401.20210928095941001',
#     'provider': '동아일보',
#     'provider_news_id': '20210928.109447051.2',
#     'published_at': '2021-09-28T00:00:00.000+09:00',
#     'title': '3일에 500만원…‘오징어게임’ 출연 거절한 외국인 “후회”'},
#    {'byline': '신혜연(shin.hyeyeon@joongang.co.kr)',
#     'category': ['IT_과학>콘텐츠', '스포츠>월드컵'],
#     'category_incident': [],
#     'dateline': '2021-09-28T11:52:14.000+09:00',
#     'enveloped_at': '2021-09-28T10:27:28.000+09:00',
#     'hilight': '"<b>오징어게임</b> 마지막에…" 축구 중계하다 결말 스포한 박문성 축구 경기 중계 도중 넷플릭스 오리지널 콘텐트 ..\'오징어 게임\'의 결말을 발설한 해설위원이 빈축을 사고 있다... .. .. .. .. 지난 26일 박문성 해설위원은 수원 삼성과 FC 서울의 93번째 슈퍼매치를 중계하다 ..\'오징어 게임\' 결말을 언급했다... FC 서울이 1대 0으로 승기를 ..',
#     'news_id': '01100901.20210928102728001',
#     'provider': '중앙일보',
#     'provider_news_id': '25010286',
#     'published_at': '2021-09-28T00:00:00.000+09:00',
#     'title': '"오징어게임 마지막에…" 축구 중계하다 결말 스포한 박문성'},
#    {'byline': '지승훈',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-28T10:38:02.000+09:00',
#     'enveloped_at': '2021-09-28T10:38:02.000+09:00',
#     'hilight': "'<b>오징어게임</b>' 인기 폭발...위하준, SNS 팔로워 280만 돌파 넷플릭스 시리즈 ..'오징어 게임'이 일주일만에 전세계 1위에 랭크되는 글로벌 잭팟을 터뜨리며 연일 화제를 일으키고 있는 가운데, 황준호 역으로 강렬한 존재감을 보여준 위하준에 대한 월드 팬들의 관심이 뜨겁게 폭발하고 있다. .. ..이 작품에서 위하준은 다른 주요 인물들이 목숨을 건 게..",
#     'news_id': '08100401.20210928103802001',
#     'provider': 'YTN',
#     'provider_news_id': '202109281036039138',
# ...
#     'provider': '중앙일보',
#     'provider_news_id': '25010625',
#     'published_at': '2021-09-29T00:00:00.000+09:00',
#     'title': "빨간불 움직이면 쏜다…횡단보도 앞 '오징어' 그 술래정체 [영상]"},
#    {'byline': '배정원(bae.jungwon@joongang.co.kr)',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-29T06:46:21.000+09:00',
#     'enveloped_at': '2021-09-29T06:01:02.000+09:00',
#     'hilight': "달고나·생라면이 제2의 짜파구리?…'<b>오징어게임</b> 열풍'에 동참한 K푸드 넷플릭스 드라마 ..‘오징어 게임’이 전 세계적으로 돌풍을 일으키면서 극중 등장한 소품도 화제가 되고 있다... 달고나 뽑기와 생라면 같은 추억의 먹거리에서부터 구슬치기, 딱지치기 등 한국 어린이 놀이를 체험하려는 소비자가 국내외 할 것 없이 늘고 있다... .. .. .. .. 28..",
#     'news_id': '01100901.20210929060102001',
#     'provider': '중앙일보',
#     'provider_news_id': '25010642',
#     'published_at': '2021-09-29T00:00:00.000+09:00',
#     'title': "달고나·생라면이 제2의 짜파구리?…'오징어게임 열풍'에 동참한 K푸드"},
#    {'byline': '김수산 리포터',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-29T07:05:00.000+09:00',
#     'enveloped_at': '2021-09-29T07:05:00.000+09:00',
#     'hilight': '[이슈톡] ..\'<b>오징어게임</b>\' 따라잡기..달고나 만들기 유행 넷플릭스 드라마 ..\'오징어 게임\' 인기에 해외 누리꾼들이 달고나에 관심이 높다는데요... .. .. ..세 번째 키워드는 .."\'<b>오징어게임</b>\' 따라잡기 세계는 ..\'달고나\' 열풍"입니다... .. .. ..드라마에서 나온 생존 게임 6개 중 하나인 ..\'달고나 뽑기\'! .. ..요즘 해외 누리꾼..',
#     'news_id': '08100201.20210929070500002',
#     'provider': 'MBC',
#     'provider_news_id': '6303643',
#     'published_at': '2021-09-29T00:00:00.000+09:00',
#     'title': "[이슈톡] '오징어게임' 따라잡기..달고나 만들기 유행"},
#    {'byline': '김재영',
#     'category': ['IT_과학>콘텐츠', '국제>중국', 'IT_과학>모바일'],
#     'category_incident': [],
#     'dateline': '2021-09-29T07:36:43.000+09:00',
#     'enveloped_at': '2021-09-29T07:36:43.000+09:00',
#     'hilight': '"<b>오징어게임</b>도 당했다"‥해적판 기승 ..\'<b>오징어게임</b>\'이 세계적인 인기를 끌고 있다는 소식 연일 전해지고 있는데, 숨이 턱 막히는 소식도 있습니다. ..\'<b>오징어게임</b>\'의 영상이 중국 인터넷 사이트에 올라와 있습니다. ....<b>오징어게임</b>\'을 해시태그로 검색한 누적 조회 수는 무려 14억 여 건, 불법 영상을 손쉽게 검색할 수도 ..\'<b>오징어게임</b>\'을 볼 수 있는 ..',
#     'news_id': '08100201.20210929073643004',
#     'provider': 'MBC',
#     'provider_news_id': '6303655',
#     'published_at': '2021-09-29T00:00:00.000+09:00',
#     'title': '[재택플러스] "오징어게임도 당했다"‥해적판 기승'},
#    {'byline': '이유나',
#     'category': ['문화>방송_연예', 'IT_과학>콘텐츠', '문화>영화'],
#     'category_incident': [],
#     'dateline': '2021-09-29T12:14:02.000+09:00',
#     'enveloped_at': '2021-09-29T12:08:02.000+09:00',
#     'hilight': "[Y터뷰③] ..'<b>오징어게임</b>' 이정재가 밝힌 ..#옥의티 ..#징검다리 ..#빨간머리 배우 이정재가 ..'오징어 게임'의 이모저모를 밝혔다. .. ..넷플릭스 시리즈 ..'오징어 게임'이 한국 드라마 최초로 넷플릭스 전세계 TV프로그램 부문 1위를 차지하며 돌풍을 일으키고 있다... .. .. ..주연을 맡은 배우 이정재에 대한 글로벌 팬들의 관심도 높..",
#     'news_id': '08100401.20210929120802003',
#     'provider': 'YTN',
#     'provider_news_id': '202109291206586274',
#     'published_at': '2021-09-29T00:00:00.000+09:00',
#     'title': "[Y터뷰③] '오징어게임' 이정재가 밝힌 #옥의티 #징검다리 #빨간머리"},
#    {'byline': '이유나',
#     'category': ['문화>영화', '문화>방송_연예', 'IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-29T12:12:02.000+09:00',
#     'enveloped_at': '2021-09-29T12:08:02.000+09:00',
#     'hilight': '[Y터뷰④] ..\'<b>오징어게임</b>\' 이정재 .."시즌2 나온다면 이병헌과 작업하고파" 배우 이정재가 ..\'<b>오징어게임</b>\'에 특별출연한 이병헌과의 우정을 언급했다. .. ..넷플릭스 시리즈 ..\'오징어 게임\'이 한국 드라마 최초로 넷플릭스 전세계 TV프로그램 부문 1위를 차지하며 돌풍을 일으키고 있다... .. .. ..주연을 맡은 배우 이정재에 대한 글로벌 팬들..',
#     'news_id': '08100401.20210929120802001',
#     'provider': 'YTN',
#     'provider_news_id': '202109291206524131',
#     'published_at': '2021-09-29T00:00:00.000+09:00',
#     'title': '[Y터뷰④] \'오징어게임\' 이정재 "시즌2 나온다면 이병헌과 작업하고파"'},
#    {'byline': '이유나',
#     'category': ['문화>방송_연예', '문화>영화', 'IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-29T12:12:04.000+09:00',
#     'enveloped_at': '2021-09-29T12:08:03.000+09:00',
#     'hilight': '[Y터뷰②] ..\'<b>오징어게임</b>\' 이정재 .."일남役 오영수 선생님, 생각 젊으시고 호흡 잘 맞아" 배우 이정재가 드라마에서 오일남 역을 맡은 배우 오영수를 언급했다. .. ..넷플릭스 시리즈 ..\'오징어 게임\'이 한국 드라마 최초로 넷플릭스 전세계 TV프로그램 부문 1위를 차지하며 돌풍을 일으키고 있다... .. .. ..주연을 맡은 배우 이정재에 대한 ..',
#     'news_id': '08100401.20210929120803001',
#     'provider': 'YTN',
#     'provider_news_id': '202109291207069757',
#     'published_at': '2021-09-29T00:00:00.000+09:00',
#     'title': '[Y터뷰②] \'오징어게임\' 이정재 "일남役 오영수 선생님, 생각 젊으시고 호흡 잘 맞아"'},
#    {'byline': '이유나',
#     'category': ['IT_과학>콘텐츠', '문화>방송_연예', '문화>영화'],
#     'category_incident': [],
#     'dateline': '2021-09-29T12:12:04.000+09:00',
#     'enveloped_at': '2021-09-29T12:08:04.000+09:00',
#     'hilight': '[Y터뷰①] ..\'<b>오징어게임</b>\' 이정재 .."드라마 보며 한참 웃어...달고나 핥으며 현타" 배우 이정재가 ..\'오징어 게임\'에서 성기훈 캐릭터를 연기한 비화를 밝혔다. .. ..넷플릭스 시리즈 ..\'오징어 게임\'이 한국 드라마 최초로 넷플릭스 전세계 TV프로그램 부문 1위를 차지하며 돌풍을 일으키고 있다... .. .. ..주연을 맡은 배우 이정재에 대..',
#     'news_id': '08100401.20210929120804001',
#     'provider': 'YTN',
#     'provider_news_id': '202109291207138560',
#     'published_at': '2021-09-29T00:00:00.000+09:00',
#     'title': '[Y터뷰①] \'오징어게임\' 이정재 "드라마 보며 한참 웃어...달고나 핥으며 현타"'},
#    {'byline': '이혜운 기자',
#     'category': ['문화>방송_연예', '문화>영화', 'IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-29T13:05:58.000+09:00',
#     'enveloped_at': '2021-09-29T13:07:11.000+09:00',
#     'hilight': '이정재 ..“<b>오징어게임</b> 속 내모습? 확실히 오징어 됐죠” 과거 배우 이정재는 모래시계 재희였고, 태양은 없다 홍기였고, 신세계 이자성이었다... .. .. .. ..그랬던 그가 어느 순간 염라대왕(신과 함께)과 수양대군(관상)이 되더니, 이제는 전 세계 찌질남 ..‘성기훈’이 돼 돌아왔다... .. .. .. ..데뷔 28년 만에 강제로 해외 진출 당한..',
#     'news_id': '01100801.20210929130711001',
#     'provider': '조선일보',
#     'provider_news_id': '2021092901221',
#     'published_at': '2021-09-29T00:00:00.000+09:00',
#     'title': '이정재 “오징어게임 속 내모습? 확실히 오징어 됐죠”'},
#    {'byline': '손효주',
#     'category': ['문화>방송_연예', 'IT_과학>콘텐츠', '문화>영화'],
#     'category_incident': [],
#     'dateline': '2021-09-29T04:50:00.000+09:00',
#     'enveloped_at': '2021-09-29T13:55:57.000+09:00',
#     'hilight': '이정재 ..“달고나 핥을..‘<b>오징어게임</b>’으로 글로벌 스타가 된 배우 이정재는 29일 화상으로 진행된 언론 공동 인터뷰에서 이같이 말했다...‘<b>오징어게임</b>’은 23일부터 엿새 연속으로 넷플릭스 TV쇼 부문 세계 스트리밍 순위 1위 자리를 지키는 등 한국 드라마의 역사를 새로 쓰고 있다...‘<b>오징어게임</b>’의 명장면 중 하나로 꼽히는 달고나 핥는 장면에 대해선 ..',
#     'news_id': '01100401.20210929135557001',
#     'provider': '동아일보',
#     'provider_news_id': '20210929.109472308.1',
#     'published_at': '2021-09-29T00:00:00.000+09:00',
#     'title': '이정재 “달고나 핥을때 ‘이렇게까지 해야하나’ 싶었죠…확실히 오징어 됐다”'},
#    {'byline': '신혜연(shin.hyeyeon@joongang.co.kr)',
#     'category': ['문화>방송_연예', 'IT_과학>콘텐츠', '문화>영화'],
#     'category_incident': [],
#     'dateline': '2021-09-30T00:00:01.000+09:00',
#     'enveloped_at': '2021-09-29T14:08:28.000+09:00',
#     'hilight': '"달고나 그렇게 핥아야 했나" 이정재가 꼽은 <b>오징어게임</b> 장면 미남 배우로 꼽히는 이정재(49)가 .."넷플릭스 시리즈 ..\'오징어 게임\'을 통해 오징어가 됐다"고 밝혀 웃음을 자아냈다... .. .. .. .. 이정재는 29일 오전 화상으로 진행된 라운드 인터뷰에서 ..\'오징어 게임\' 출연과 관련한 뒷이야기들을 털어놓았다... 넷플릭스 오리지널 콘텐트 ..',
#     'news_id': '01100901.20210929140828001',
#     'provider': '중앙일보',
#     'provider_news_id': '25010750',
#     'published_at': '2021-09-29T00:00:00.000+09:00',
#     'title': '"달고나 그렇게 핥아야 했나" 이정재가 꼽은 오징어게임 장면'},
#    {'byline': '이유나',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-29T14:54:02.000+09:00',
#     'enveloped_at': '2021-09-29T14:50:03.000+09:00',
#     'hilight': '[Y터뷰②] ..\'<b>오징어게임</b>\' 박해수 .."해외 인기 영광...퇴폐미 언급 기분 좋아" 배우 박해수가 ..\'오징어 게임\'에서 상우 캐릭터를 연기한 비화를 밝혔다. .. ..넷플릭스 시리즈 ..\'오징어 게임\'이 한국 드라마 최초로 넷플릭스 전세계 TV프로그램 부문 1위를 차지하며 돌풍을 일으키고 있다... .. .. ..주연을 맡은 배우 박해수를 향한 글..',
#     'news_id': '08100401.20210929145003001',
#     'provider': 'YTN',
#     'provider_news_id': '202109291449549058',
#     'published_at': '2021-09-29T00:00:00.000+09:00',
#     'title': '[Y터뷰②] \'오징어게임\' 박해수 "해외 인기 영광...퇴폐미 언급 기분 좋아"'},
#    {'byline': '이유나',
#     'category': ['IT_과학>콘텐츠', '문화>방송_연예', '문화>영화'],
#     'category_incident': [],
#     'dateline': '2021-09-29T14:56:02.000+09:00',
#     'enveloped_at': '2021-09-29T14:52:03.000+09:00',
#     'hilight': '[Y터뷰③] ..\'<b>오징어게임</b>\' 박해수 .."이정재에 감동....정호연·이유미·아누팜과 친해져" 배우 박해수가 ..\'오징어 게임\' 동료 배우들을 향한 애정을 드러냈다. .. ..넷플릭스 시리즈 ..\'오징어 게임\'이 한국 드라마 최초로 넷플릭스 전세계 TV프로그램 부문 1위를 차지하며 돌풍을 일으키고 있다... .. .. ..주연을 맡은 배우 박해수를 향한..',
#     'news_id': '08100401.20210929145203003',
#     'provider': 'YTN',
#     'provider_news_id': '202109291450576554',
#     'published_at': '2021-09-29T00:00:00.000+09:00',
#     'title': '[Y터뷰③] \'오징어게임\' 박해수 "이정재에 감동....정호연·이유미·아누팜과 친해져"'},
#    {'byline': '옥기원 기자',
#     'category': ['IT_과학>콘텐츠', 'IT_과학>모바일'],
#     'category_incident': [],
#     'dateline': '2021-09-30T02:50:09.000+09:00',
#     'enveloped_at': '2021-09-29T15:10:21.000+09:00',
#     'hilight': '달고나, 양은 도시락, 생라면…추억의 K-푸드 소환한 ..‘<b>오징어게임</b>’ 넷플릭스 드라마 ..‘오징어 게임’의 전세계적 열풍과 더불어 온라인 쇼핑몰에서 .. <b>오징어게임</b>이란 열쇳말이 포함된 파티가면 판매량도 500%나 증가했다... 11번가에선 27일 잇따라 <b>오징어게임</b>굿즈가 실시간 쇼핑 검색어 1위에 오르기도 했다... 농심은 <b>오징어게임</b>과 비슷한 스타일의 ..',
#     'news_id': '01101001.20210929151021004',
#     'provider': '한겨레',
#     'provider_news_id': '1013190',
#     'published_at': '2021-09-29T00:00:00.000+09:00',
#     'title': '달고나, 양은 도시락, 생라면…추억의 K-푸드 소환한 ‘오징어게임’'},
#    {'byline': '김은성 기자 kes@kyunghyang.com',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-30T16:16:49.000+09:00',
#     'enveloped_at': '2021-09-29T16:14:14.000+09:00',
#     'hilight': '<b>오징어게임</b> 돌풍에 K라면·굿즈 흥행 잇나 넷플릭스 오리지널 시리즈 ..<<b>오징어게임</b>>이 전세계적으로 돌풍을 일으키면서 작품에 등장한 상품들도 덩달아 인기를 끌고 있다...‘<b>오징어게임</b> 굿즈’ 등이 검색어로 등장했고 유통업계는 연관 마케팅을 시작했다.....<b>오징어게임</b>>이라는 키워드..<<b>오징어게임</b>> 속 인물이 입었던 다양한 코스프레 의상들이 주로 팔리고 있다...',
#     'news_id': '01100101.20210929161414001',
#     'provider': '경향신문',
#     'provider_news_id': '202109291613001',
#     'published_at': '2021-09-29T00:00:00.000+09:00',
#     'title': '오징어게임 돌풍에 K라면·굿즈 흥행 잇나'},
#    {'byline': '김형근',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-30T01:38:02.000+09:00',
#     'enveloped_at': '2021-09-29T19:34:02.000+09:00',
#     'hilight': '외신도 ..\'<b>오징어게임</b>\' 조명..."전세계 강타한 지옥같은 호러쇼" 한국 드라마 ..\'오징어 게임\'의 전 세계적 돌풍에 외신도 발 빠른 반응을 내놓으며 조명하고 있습니다. .. ..영국 일간 가디언은 .."오징어 게임, 전 세계를 사로잡은 지옥 같은 호러쇼"라는 제목의 기사를 통해 돌풍의 배경을 분석했습니다. .. ..신문은 .."이 드라마는 넷플릭스 ..',
#     'news_id': '08100401.20210929193402001',
#     'provider': 'YTN',
#     'provider_news_id': '202109291932188808',
#     'published_at': '2021-09-29T00:00:00.000+09:00',
#     'title': '외신도 \'오징어게임\' 조명..."전세계 강타한 지옥같은 호러쇼"'},
#    {'byline': '김명일 기자',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-29T21:24:26.000+09:00',
#     'enveloped_at': '2021-09-29T21:25:35.000+09:00',
#     'hilight': '“화촌데유” ..“아줌마 보니 누구 생각나네” 이재명 게임도 나..‘<b>오징어게임</b>’이 큰 인기를 끌면서 온라인상에서는 이를 패러디한 정치 풍자 게시글이 잇따라 등장하고 있다...‘<b>오징어게임</b>’을 패러디한 ..‘<b>오징어게임</b>’은 456억원의 상금이 걸린 의문의 서바이벌에 참가한 사람들이 최후의 승자가 되기 위해 목숨을 걸고 극한의 게임에 도전하는 이야기를 그렸다...',
#     'news_id': '01100801.20210929212535001',
#     'provider': '조선일보',
#     'provider_news_id': '2021092902456',
#     'published_at': '2021-09-29T00:00:00.000+09:00',
#     'title': '“화촌데유” “아줌마 보니 누구 생각나네” 이재명 게임도 나왔다'},
#    {'byline': '이보람(lee.boram2@joongang.co.kr)',
#     'category': ['IT_과학>콘텐츠', '정치>청와대'],
#     'category_incident': [],
#     'dateline': '2021-09-30T06:36:18.000+09:00',
#     'enveloped_at': '2021-09-29T23:24:03.000+09:00',
#     'hilight': '“구슬 기본소득” ..“화촌데유?” 이번엔 ..‘이재명 게임’ 나..‘<b>오징어게임</b>’이 큰 인기를 끌면서 우리나라 정치 현실을 빗댄 각종 패러디물이 나오는 가운데 이번엔 .. 29일 디시인사이드 등 온라인커뮤니티에는 <b>오징어게임</b>을 패러디에 이용한 ..“문재인 게임 후속작 이재명 게임이 나왔다”며 <b>오징어게임</b> 장면에 관련 자막을 합성한 자료 여러 장을 공유했다...',
#     'news_id': '01100901.20210929232403001',
#     'provider': '중앙일보',
#     'provider_news_id': '25010945',
#     'published_at': '2021-09-29T00:00:00.000+09:00',
#     'title': '“구슬 기본소득” “화촌데유?” 이번엔 ‘이재명 게임’ 나왔다'},
#    {'byline': '이보람(lee.boram2@joongang.co.kr)',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': ['사회>사회문제>중독'],
#     'dateline': '2021-09-30T06:40:59.000+09:00',
#     'enveloped_at': '2021-09-30T00:15:17.000+09:00',
#     'hilight': '‘<b>오징어게임</b>’ 인기에 봉준호 감독 ..‘기생충’ 소환된 이유는 넷플릭스 오리지널 시리즈 ..‘오징어 게임’이 전 세계적인 인기를 끌면서 외신들도 이 드라마에 주목하고 있다... 외신들은 특히 2019년 오스카상을 받았던 봉준호 감독의 영화 ..‘기생충’을 소환해 <b>오징어게임</b>의 인기 비결을 분석했다... .. .. .. .. 28일(현지시간) 영국 언론 가..',
#     'news_id': '01100901.20210930001517001',
#     'provider': '중앙일보',
#     'provider_news_id': '25011092',
#     'published_at': '2021-09-30T00:00:00.000+09:00',
#     'title': '‘오징어게임’ 인기에 봉준호 감독 ‘기생충’ 소환된 이유는'},
#    {'byline': '김도형',
#     'category': ['IT_과학>콘텐츠', 'IT_과학>모바일', '문화>영화'],
#     'category_incident': [],
#     'dateline': '2021-09-29T18:00:00.000+09:00',
#     'enveloped_at': '2021-09-30T03:02:06.000+09:00',
#     'hilight': '“제2 <b>오징어게임</b> 잡아라”… K웹툰-소설 영상제작 채비 넷플릭스 오리지널 시리즈인 ..‘<b>오징어게임</b>’이 전 세계적인 흥행 돌풍으로 이른바 ..‘K콘텐츠’ 산업의 경쟁력을 입증하면서 웹툰과 웹소설 분야가 새로운 슈퍼 콘텐츠로 기대를 모으고 있다... 한국이 종주국과 같은 위상을 가지고 있는 웹툰의 경우 영상으로 쉽게 확장할 수 있는 지식재산권(IP)이어서 ..',
#     'news_id': '01100401.20210930030206001',
#     'provider': '동아일보',
#     'provider_news_id': '20210930.109481661.1',
#     'published_at': '2021-09-30T00:00:00.000+09:00',
#     'title': '“제2 오징어게임 잡아라”… K웹툰-소설 영상제작 채비'},
#    {'byline': '김상운 문화부 차장',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-29T18:00:00.000+09:00',
#     'enveloped_at': '2021-09-30T03:02:21.000+09:00',
#     'hilight': '‘<b>오징어게임</b>’도 다방구 같은 동네놀이에서 비롯됐다... 드라마에서는 <b>오징어게임</b>을 비롯해 .. 이 중 유독 <b>오징어게임</b>을 제목으로 정한 데 대해 연출을 맡은 황동혁 감독은 ....<b>오징어게임</b>을 해본 적이 없는 30대..‘<b>오징어게임</b>’의 흥행은 온고지신(溫故知新)의 지혜가 중요하다는 걸 새삼 깨닫게 해준다...‘<b>오징어게임</b>’ 열풍은 과거의 가치를 되돌아보게 한다...',
#     'news_id': '01100401.20210930030221002',
#     'provider': '동아일보',
#     'provider_news_id': '20210930.109481832.1',
#     'published_at': '2021-09-30T00:00:00.000+09:00',
#     'title': '[광화문에서/김상운]‘오징어 게임’의 부활과 온고지신의 지혜'},
#    {'byline': '이유나',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-30T10:34:04.000+09:00',
#     'enveloped_at': '2021-09-30T10:34:04.000+09:00',
#     'hilight': "[Y초점] 미국 이어 영국, 프랑스까지...넷플릭스 공식 SNS 점령한 ..'<b>오징어게임</b>' 어쩌면 넷플릭스에서 역대 가장 시청자수가 많은 작품이 될 지도 모른다... 넷플릭스가 야심차게 선보인 K-콘텐츠 ..'<b>오징어게임</b>'과 관련된 글들이 게시되고 있으며, 해당 글들의 리트윗, 공감 수는 타 작품과 관련된 글들에 비해 월등히 높은 수치를 기록 중이다. ..",
#     'news_id': '08100401.20210930103404001',
#     'provider': 'YTN',
#     'provider_news_id': '202109301031578639',
#     'published_at': '2021-09-30T00:00:00.000+09:00',
#     'title': "[Y초점] 미국 이어 영국, 프랑스까지...넷플릭스 공식 SNS 점령한 '오징어게임'"},
#    {'byline': '김성현',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-30T10:46:02.000+09:00',
#     'enveloped_at': '2021-09-30T10:46:02.000+09:00',
#     'hilight': '[Y터뷰②] ..\'오징어 게임\' 위하준 .."시즌2? 예상할 수 없지만 출연 욕심 있어" 넷플릭스 시리즈 ..\'오징어 게임\'에 출연한 위하준이 다음 시즌에 대한 출연 희망 의사를 전했다... .. .. ..30일 오전 YTN star는 넷플릭스 시리즈 ..\'오징어 게임\'에 출연..\'<b>오징어게임</b>\' 프리퀄로 준호 형제 이야기를 상상해본 적이 있냐는 질문에는 ..',
#     'news_id': '08100401.20210930104602001',
#     'provider': 'YTN',
#     'provider_news_id': '202109301044022543',
#     'published_at': '2021-09-30T00:00:00.000+09:00',
#     'title': '[Y터뷰②] \'오징어 게임\' 위하준 "시즌2? 예상할 수 없지만 출연 욕심 있어"'},
#    {'byline': '윤기은 기자 energyeun@kyunghyang.com',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-30T15:12:51.000+09:00',
#     'enveloped_at': '2021-09-30T10:50:53.000+09:00',
#     'hilight': '\'오징어 게임\' 흥행 이유?···CNN .."정말 끝내준다, ..\'기생충\' 현상과 같아" 호평 외신들이 7일째 넷플릭스 전세계 TV부문 1위를 차지하고 있는 한국 오리지널 드라마 ..<오징어 게임>에 대한 호평과 함께 인기 이유를 분석했다. .. ..CNN은 29일(현지시간) ..‘<오징어 게임>은 무엇이고 왜 사로잡는가’라는 제목의 ..‘<b>오징어게임</b>’ ..',
#     'news_id': '01100101.20210930105053001',
#     'provider': '경향신문',
#     'provider_news_id': '202109301050001',
#     'published_at': '2021-09-30T00:00:00.000+09:00',
#     'title': '\'오징어 게임\' 흥행 이유?···CNN "정말 끝내준다, \'기생충\' 현상과 같아" 호평'},
#    {'byline': '이해준(lee.hayjune@joongang.co.kr)',
#     'category': ['IT_과학>콘텐츠'],
#     'category_incident': [],
#     'dateline': '2021-09-30T15:09:45.000+09:00',
#     'enveloped_at': '2021-09-30T13:15:14.000+09:00',
#     'hilight': "'오징어 게임' 혹독한 수익 룰···설계자 넷플릭스가 다 먹는다 영화 ..‘극한직업’은 지난 2019년 1600만이 넘는 관객을 동원하며 1300억원이 넘는 매출액을 기록했다...‘<b>오징어게임</b>’에는 다른 게임의 룰이 적용된다... <b>오징어게임</b> 8부작에 넷플릭스가 투입한 제작비는 약 200억원으로 알려졌다...‘<b>오징어게임</b>’이 보여준 성과에 주목하고 있다...",
#     'news_id': '01100901.20210930131514001',
#     'provider': '중앙일보',
#     'provider_news_id': '25011238',
#     'published_at': '2021-09-30T00:00:00.000+09:00',
#     'title': "'오징어 게임' 혹독한 수익 룰···설계자 넷플릭스가 다 먹는다"}],
#   'total_hits': 107}}

# %%
len(js['return_object']['documents'][0]['hilight'])
# Out:
# 205

# %% [markdown]
# # 3. 뉴스 상세정보 조회 API

# %%
url = 'http://tools.kinds.or.kr:8888/search/news'

datas = {
    "access_key": "9af2f705-2974-4340-8b55-d69040b944ab",

    "argument": {
        "news_ids": [
                    "01101001.20180731114940001",
                    ],
                
        "fields": [
                "content",
                "byline",
                "category",
                "category_incident",
                "images",
                "provider_subject",
                "provider_news_id",
                "publisher_code"
                ]
                }
 }

response = requests.post(url, data=json.dumps(datas))
response.json()
# Out:
# {'result': 0,
#  'return_object': {'documents': [{'byline': '정의길',
#     'category': ['국제>아시아', '국제>미국_북미', '국제>유럽_EU'],
#     'category_incident': ['범죄>범죄일반>유괴/납치',
#      '사고>교통사고>항공사고',
#      '사고>교통사고>해상사고',
#      '사회>사회문제>자살'],
#     'content': '운항 도중 흔적도 없이 사라진 ‘말레이시아항공 370’(MH-370) 여객기 실종 사건은 결국 항공 사상 최대 미스터리로 남게 됐다. \n\n 말레이시아 정부는 30일 펴낸 MH-370편 실종사건에 대한 495쪽에 달하는 공식 최종 보고서에서 “충분한 증거가 없어 이번 사건이 발생한 원인을 명확히 특정하지 못했다”는 결론을 내렸다. 이 보고서는 여객기 실종..',
#     'dateline': '2018-07-31T20:38:23.000+09:00',
#     'enveloped_at': '2018-07-31T11:49:40.000+09:00',
#     'images': '/01101001/2018/07/31/01101001.20180731114940001.01.jpg\n/01101001/2018/07/31/01101001.20180731114940001.02.jpg',
#     'news_id': '01101001.20180731114940001',
#     'provider': '한겨레',
#     'provider_news_id': '855582',
#     'provider_subject': [{'subject_info': '국제',
#       'subject_info1': '',
#       'subject_info2': '',
#       'subject_info3': '',
#       'subject_info4': ''}],
#     'published_at': '2018-07-31T00:00:00.000+09:00',
#     'publisher_code': '',
#     'title': '말레이 항공기 실종, 영구 미제로…사고 원인 규명 못해'}],
#   'total_hits': 1}}

# %% [markdown]
# # 4. 오늘의 이슈 API

# %%
url = 'http://tools.kinds.or.kr:8888/issue_ranking'

datas = {
    "access_key": "9af2f705-2974-4340-8b55-d69040b944ab",

    "argument": {
                "date": "2021-09-29",
                "provider": []
                }
}

response = requests.post(url, data=json.dumps(datas))
response.json()
# Out:
# {'result': 0,
#  'return_object': {'date': '2021-09-29',
#   'topics': [{'news_cluster': ['01500601.20210929165230001',
#      '01100201.20210929164711001',
#      '01100101.20210929164711001',
#      '01100611.20210929164454001',
#      '01100901.20210929164234001',
#      '02100201.20210929163506001',
#      '08100401.20210929162603001',
#      '01100611.20210929162242001',
#      '01100101.20210929161011001',
#      '07101201.20210929155416001',
#      '07101201.20210929154138001',
#      '08100401.20210929153605002',
#      '08100401.20210929153402001',
#      '01100501.20210929150004001',
#      '01100801.20210929145526001',
#      '01400601.20210929145437001',
#      '01100901.20210929144416001',
#      '01100901.20210929144114001',
#      '02100851.20210929142517001',
#      '01100901.20210929141932001',
#      '01100201.20210929141926001',
#      '01400501.20210929141420001',
#      '02100101.20210929141007002',
#      '01100801.20210929140736001',
#      '02100201.20210929134851001',
#      '02100201.20210929134848001',
#      '01100701.20210929134845001',
#      '02100701.20210929133704001',
#      '01100701.20210929133354001',
#      '01100701.20210929132240001',
#      '01100701.20210929131902002',
#      '01100301.20210929131544005',
#      '01100301.20210929131544003',
#      '01100301.20210929131543007',
#      '01100301.20210929131533003',
#      '02100851.20210929130439001',
#      '02100201.20210929125853001',
#      '02100201.20210929125800001',
#      '08100401.20210929125003001',
#      '08100401.20210929124203001',
#      '08100201.20210929121955001',
#      '02100801.20210929121125001',
#      '08100101.20210929121023001',
#      '01100501.20210929121005008',
#      '08200101.20210929120404002',
#      '02100801.20210929120127001',
#      '01100501.20210929120006013',
#      '08100401.20210929120003002',
#      '01100901.20210929114802001',
#      '01100901.20210929114554001',
#      '02100201.20210929114453001',
#      '01101001.20210929114008001',
#      '01100501.20210929113005001',
#      '01100501.20210929113005003',
#      '01500601.20210929112940001',
#      '01100801.20210929112923001',
#      '08100401.20210929112802001',
#      '01100611.20210929111257001',
#      '08100401.20210929111204001',
#      '02100201.20210929111038001',
#      '02100801.20210929110635001',
#      '01100101.20210929110414001',
#      '02100701.20210929110301003',
#      '01100701.20210929110243003',
#      '01101001.20210929110027001',
#      '01500701.20210929105739001',
#      '01500701.20210929105732001',
#      '08100401.20210929105602001',
#      '01100701.20210929105217001',
#      '01100701.20210929105002001',
#      '02100701.20210929104903001',
#      '01100801.20210929104843001',
#      '01100701.20210929104503002',
#      '01100611.20210929103810001',
#      '02100851.20210929103508001',
#      '02100701.20210929103426001',
#      '01101101.20210929103248001',
#      '01100701.20210929103234001',
#      '01101001.20210929103004001',
#      '01200201.20210929102611001',
#      '02100801.20210929102439001',
#      '08100401.20210929102404002',
#      '08100401.20210929102234001',
#      '01100101.20210929101807002',
#      '07101201.20210929101221001',
#      '02100201.20210929100739001',
#      '02100801.20210929100728001',
#      '02100801.20210929100643001',
#      '01101101.20210929100642001',
#      '02100201.20210929100630001',
#      '02100201.20210929100625001',
#      '08100401.20210929100603002',
#      '02100701.20210929100552001',
#      '02100601.20210929100533001',
#      '02100311.20210929100528001',
#      '01100201.20210929100404001',
#      '01100611.20210929100310001',
#      '08200101.20210929100045002',
#      '01100401.20210929100002001',
#      '01100101.20210929095952001',
#      '01500601.20210929095633001',
#      '02100801.20210929095621001',
#      '01100401.20210929095538001',
#      '01100901.20210929095535001',
#      '01100901.20210929095512001',
#      '02100101.20210929095512002',
#      '02100601.20210929095406001',
#      '02100851.20210929095239001',
#      '02100701.20210929095140001',
#      '01100201.20210929095121001',
#      '01100901.20210929095044001',
#      '02100801.20210929094610001',
#      '01100801.20210929094452001',
#      '01200201.20210929094429001',
#      '02100311.20210929094429001',
#      '08100401.20210929094403002',
#      '08100401.20210929094403001',
#      '08100201.20210929094345001',
#      '08100201.20210929094344003',
#      '08100401.20210929094202001',
#      '07101201.20210929094148001',
#      '01100401.20210929093128001',
#      '01101001.20210929093018001',
#      '08100401.20210929092805001',
#      '02100101.20210929092508002',
#      '08100401.20210929092402001',
#      '01100701.20210929092054001',
#      '01100701.20210929091904001',
#      '02100851.20210929091753001',
#      '08100101.20210929091436001',
#      '01100701.20210929091251001',
#      '08100101.20210929091128001',
#      '01100901.20210929090800001',
#      '02100601.20210929090535001',
#      '01100201.20210929085810001',
#      '07101201.20210929085128001',
#      '08100401.20210929084003001',
#      '01100611.20210929082803001',
#      '01500601.20210929082554001',
#      '02100851.20210929080134001'],
#     'topic': "검찰, '대장동 의혹' 화천대유 압수수색",
#     'topic_keyword': '대장동,수사,의혹,검찰,화천,화천대유,대유,수수,압수수색,수색,수사팀,전담,구성,동시,유동규,동시다발,전담수사팀,특혜,다발,동인,총장,천화동인,출국,천화동,출국금지,핵심,인물,승인,박범계,본격화,규모,검찰총장,소환,의지,성남,규명,특별수사,압색,곽상도,전담팀,녹취,경찰,천하동인,이재명,녹취록,검사,김만배,4호,16명,확보',
#     'topic_rank': 140},
#    {'news_cluster': ['02100851.20210929165929001',
#      '02100851.20210929165922001',
#      '02100201.20210929165751001',
#      '01100101.20210929165418001',
#      '01100701.20210929165154001',
#      '02100701.20210929165003001',
#      '02100701.20210929164559001',
#      '02100801.20210929164502002',
#      '02100801.20210929164138001',
#      '01100101.20210929164134001',
#      '02100201.20210929163359001',
#      '08100401.20210929162803001',
#      '02100701.20210929162632002',
#      '02100311.20210929161712001',
#      '02100201.20210929161620001',
#      '07101201.20210929161145001',
#      '02100201.20210929161043001',
#      '02100701.20210929161018001',
#      '02100801.20210929160604001',
#      '01700201.20210929160029002',
#      '01100501.20210929160004002',
#      '07100501.20210929155840001',
#      '08100401.20210929155622003',
#      '01100701.20210929155428001',
#      '01100401.20210929155426001',
#      '02100701.20210929155134001',
#      '02100851.20210929154909001',
#      '02100801.20210929154615001',
#      '02100701.20210929153708001',
#      '08100401.20210929153602001',
#      '02100201.20210929153513001',
#      '01100701.20210929153306001',
#      '01100901.20210929153149001',
#      '02100201.20210929152846001',
#      '01100611.20210929152747001',
#      '02100701.20210929152706001',
#      '01100101.20210929152351002',
#      '02100801.20210929152135001',
#      '01101001.20210929152019001',
#      '02100101.20210929152008001',
#      '01500701.20210929151902001',
#      '01100101.20210929151850001',
#      '02100311.20210929151654001',
#      '01100801.20210929151537001',
#      '01500601.20210929151436001',
#      '01100901.20210929151427001',
#      '01101101.20210929151406001',
#      '01100611.20210929151330001',
#      '08100401.20210929151202001',
#      '02100201.20210929151117001',
#      '01101001.20210929151021002',
#      '07100501.20210929150945001',
#      '01100201.20210929150849001',
#      '02100701.20210929150835001',
#      '02100601.20210929150748001',
#      '02100851.20210929150748001',
#      '01100401.20210929150746001',
#      '01100501.20210929150004002',
#      '01100101.20210929145908001',
#      '08100401.20210929145802001',
#      '01100701.20210929145106001',
#      '01100611.20210929144355001',
#      '02100801.20210929144112001',
#      '01100201.20210929143933001',
#      '02100701.20210929143632001',
#      '02100851.20210929142818001',
#      '01100611.20210929142317001',
#      '02100201.20210929142147001',
#      '01500601.20210929141832001',
#      '02100601.20210929141802001',
#      '02100701.20210929141736001',
#      '01101101.20210929141700001',
#      '02100701.20210929141628002',
#      '01100901.20210929141546001',
#      '02100701.20210929141544001',
#      '08100401.20210929141402001',
#      '01100801.20210929141009001',
#      '02100851.20210929134617001',
#      '02100701.20210929134130001',
#      '02100851.20210929130922001',
#      '08100101.20210929123901001',
#      '01100501.20210929121005002',
#      '01100501.20210929120006004',
#      '01100501.20210929120006005',
#      '01100501.20210929120006008',
#      '02100701.20210929115815001',
#      '01100701.20210929110052001',
#      '02100851.20210929104640001',
#      '02100801.20210929102653001',
#      '08100401.20210929102404001',
#      '08100401.20210929102203001',
#      '08200101.20210929100609001',
#      '08100201.20210929094345003',
#      '08100401.20210929090402003',
#      '02100701.20210929082236001',
#      '02100201.20210929082127001',
#      '02100701.20210929082047001'],
#     'topic': '일본 국무총리에 기사다 후미오 전 일본 외무상 취임',
#     'topic_keyword': '기시다,총리,일본,투표,고노,자민당,총재,속보,합의,선거,위안부,결선,1차,유력,후미오,한일,1위,당선,100대,선출,스가,재선,예상,결선투표,총재선거,취임,vs,포스트,외무,외무상,아베,협력,지향,판명,결정,미래지향적,미래,4일,승리,등극,당사자,1표,주도,후임,2위,비둘기파,시작,2시,과반,추진',
#     'topic_rank': 97},
#    {'news_cluster': ['01100201.20210929165452001',
#      '07101201.20210929165147001',
#      '01100901.20210929164154001',
#      '08100401.20210929163802001',
#      '01101101.20210929163126001',
#      '01100901.20210929154650001',
#      '01100901.20210929152136001',
#      '01101001.20210929151021001',
#      '02100311.20210929150803001',
#      '01100901.20210929150414001',
#      '02100311.20210929142940001',
#      '01100101.20210929142407001',
#      '08100401.20210929141003003',
#      '02100201.20210929140256001',
#      '02100701.20210929135638001',
#      '02100801.20210929135250001',
#      '02100801.20210929134925001',
#      '01100901.20210929133545001',
#      '02100201.20210929133320001',
#      '01100301.20210929131537003',
#      '01100301.20210929131533006',
#      '08100401.20210929125802001',
#      '01101001.20210929123019001',
#      '01100501.20210929121005003',
#      '08200101.20210929120602001',
#      '01100901.20210929120233001',
#      '01100501.20210929120006002',
#      '01100501.20210929120006001',
#      '01100501.20210929120006012',
#      '01100701.20210929115357001',
#      '08100401.20210929114802001',
#      '08100401.20210929112402001',
#      '07101201.20210929112230001',
#      '02100701.20210929105724001',
#      '02100201.20210929105630001',
#      '08100401.20210929102402001',
#      '08100401.20210929101602001',
#      '02100701.20210929100441001',
#      '08200101.20210929100250001',
#      '08200101.20210929100044001',
#      '01101101.20210929095855001',
#      '02100701.20210929095139002',
#      '08100201.20210929094344002',
#      '08100401.20210929092803001',
#      '08100101.20210929091903001',
#      '08100401.20210929085602001',
#      '01100101.20210929085500001',
#      '01100501.20210929084004001',
#      '08100401.20210929083802001',
#      '01101001.20210929081035001',
#      '01500701.20210929080513001'],
#     'topic': '북한 "극초음속 신형 미사일 첫 실험 발사"',
#     'topic_keyword': '미사일,음속,초음속,극초음속,발사,초음속미사일,극초음속미사일,시험,8형,화성,북한,시험발사,단계,요격,초기,김정은,가능,초기단계,무력,무력화,인저,체인저,게임,도발,탐지,합참,대화,방어,신무기,신형,참관,조건,안해,방어망,게임체인저,무기,게임체,제재,수준,안팎,김여정,속도,의도,요격가능,확인,잣대,불참,미국,대응,국무부',
#     'topic_rank': 51},
#    {'news_cluster': ['08100401.20210929151202002',
#      '01100801.20210929150140001',
#      '01101001.20210929141005001',
#      '02100801.20210929140340001',
#      '01101101.20210929140134001',
#      '01100901.20210929140032001',
#      '02100201.20210929135510001',
#      '02100801.20210929133815002',
#      '02100201.20210929124229001',
#      '08100101.20210929122550001',
#      '01100501.20210929120006009',
#      '08100401.20210929115403001',
#      '02100701.20210929114957001',
#      '02100601.20210929114521001',
#      '07101201.20210929111216001',
#      '02100801.20210929110859001',
#      '02100801.20210929110304001',
#      '01500601.20210929105630001',
#      '02100201.20210929105329001',
#      '02100801.20210929105313001',
#      '02100311.20210929103134001',
#      '02100701.20210929100127001',
#      '01100701.20210929100018001',
#      '01101101.20210929094833001',
#      '08100401.20210929094803001',
#      '02100801.20210929093938001',
#      '01100801.20210929093828001',
#      '02100311.20210929093758001',
#      '02100601.20210929093358001',
#      '02100201.20210929092430001',
#      '02100101.20210929092030003',
#      '01100201.20210929091944001',
#      '02100701.20210929091712002',
#      '01100901.20210929091539001'],
#     'topic': '헝다 "자회사 보유 은행지분 매각" 1조8000억 자금 확보',
#     'topic_keyword': '헝다,지분,매각,은행,확보,보유,회사,자회사,1조,은행지분,000억,자금,중국,기업,8조,1.8조,위기,국유,정부,주식,종합,껐다,8천억,부동산,상보,증시,불만,경제,국유기업,신용등급,하향,마감,화인부동산,등급,파산,주주,피치,정지,2대,유동성,대주주,주가,거래,홍콩,하락,당선,사실상,급등,해결,압박',
#     'topic_rank': 34},
#    {'news_cluster': ['01100201.20210929165859001',
#      '02100311.20210929164933001',
#      '01100701.20210929163214001',
#      '01600801.20210929163123001',
#      '01100901.20210929162745001',
#      '02100601.20210929161239001',
#      '07101201.20210929155429001',
#      '01500601.20210929152958001',
#      '01100901.20210929152233001',
#      '02100801.20210929151802001',
#      '01100901.20210929144740001',
#      '02100801.20210929144539002',
#      '01100801.20210929140242001',
#      '08100401.20210929140202002',
#      '01100801.20210929140128001',
#      '01100401.20210929135444001',
#      '01100701.20210929134844001',
#      '01100301.20210929131544004',
#      '01100701.20210929125940001',
#      '08100201.20210929121955002',
#      '01500701.20210929121311001',
#      '01100801.20210929120232001',
#      '02100701.20210929120023001',
#      '01100201.20210929111158001',
#      '01100101.20210929103711001',
#      '01101101.20210929103136001',
#      '02100311.20210929101932001',
#      '02100601.20210929095247001',
#      '01100701.20210929085906001',
#      '01100701.20210929085756001',
#      '02100851.20210929085546001'],
#     'topic': '윤석열 "父 집 산 사람 김만배 친누나인 것 어제 처음 알았다"',
#     'topic_keyword': '석열,윤석열,부친,김만배,누나,화천대유,대유,의혹,홍준표,특검,법조,김의겸,매입,대장동,수사,자택,게이트,계약,계약서,이재명,동생,비리,국민,사이,매매,대통령,촉구,경찰,수용,수사팀,캠프,다운계약,주택,주주,부동산,연희동,다운,유승민,매수,매매계약서,카르텔,친분,논란,구성,대주주,다운계약서,공개,주자,이준석,국민의힘',
#     'topic_rank': 31},
#    {'news_cluster': ['02100601.20210929165927001',
#      '01100201.20210929162348001',
#      '01100101.20210929152351001',
#      '01100301.20210929131537006',
#      '01101001.20210929122012001',
#      '01100501.20210929122005002',
#      '01200201.20210929121620001',
#      '02100101.20210929115022002',
#      '07100501.20210929102058001',
#      '02100851.20210929101414001',
#      '01100801.20210929101046001',
#      '01100901.20210929100833001',
#      '02100701.20210929100804002',
#      '08100401.20210929100403001',
#      '02100801.20210929100230001',
#      '01500601.20210929100205001',
#      '01300101.20210929095620001',
#      '07101201.20210929094156001',
#      '01101101.20210929093714001',
#      '02100201.20210929093437001',
#      '01100701.20210929092910001',
#      '02100311.20210929092811001',
#      '01100201.20210929092127001'],
#     'topic': '정부 “물가 안정 위해 공공요금 연말까지 최대한 동결”',
#     'topic_keyword': '요금,공공요금,연말,동결,최대,정부,차관,기재차관,이억원,가스,원칙,인상,물가,도로,전기료,철도,도시가스,기재부,제동,급등,교통,신속,가격,상하수도,하수도,전기료외,대응,제외,징후,담합,안정,행안부,분산,중요,의미,적자,공동대응방안,이날,차원,재정부,쓰레기봉툿값,오름세,뉴욕상업거래소,철도요금,동결원칙,감안해,예상,공급,움직임,주관',
#     'topic_rank': 23},
#    {'news_cluster': ['08100401.20210929150004001',
#      '08100101.20210929123754002',
#      '08100201.20210929121956004',
#      '08200101.20210929114849001',
#      '01100901.20210929104157001',
#      '01100701.20210929102658002',
#      '08100401.20210929094602001',
#      '02100701.20210929093042001',
#      '02100801.20210929092226001',
#      '01101101.20210929090233001',
#      '07101201.20210929085130001',
#      '02100201.20210929083319001',
#      '01100701.20210929082921001',
#      '01100101.20210929082701001',
#      '01100201.20210929082436001',
#      '01100801.20210929081715001',
#      '01100611.20210929081249001',
#      '02100311.20210929080840001',
#      '08100401.20210929080602001'],
#     'topic': '홍남기 "20대 이하 편법증여 세무조사 착수"',
#     'topic_keyword': '조사,홍남기,편법,증여,20대,세무조사,세무,446명,편법증여,주택,10월,취득,의심,부동산,자금,재산,등록,재산등록,착수,지구,예정,공무원,구입,업무,도심,구입자금,예정지구,사업,지정,복합,도심복합사업,복합사업,추가,상승,구역,둔화,2.4대책,취득자,9000만,대책,증산4구역,신규,상승세,주택취득,신규취득,혐의,분담금,제한,집주인,가격상승세',
#     'topic_rank': 19},
#    {'news_cluster': ['08100401.20210929165202001',
#      '01101101.20210929164654001',
#      '01500701.20210929162610001',
#      '02100601.20210929153448001',
#      '01100101.20210929152910001',
#      '02100801.20210929151415001',
#      '01100401.20210929151406001',
#      '01100701.20210929151351001',
#      '01100501.20210929143005004',
#      '01101001.20210929142007002',
#      '02100851.20210929141235001',
#      '02100701.20210929134238001',
#      '08100401.20210929130605001',
#      '01100801.20210929120211001',
#      '02100201.20210929120137001',
#      '02100801.20210929120130001',
#      '01100901.20210929120123001',
#      '02100311.20210929120115001'],
#     'topic': '통계청, 한국 노인 빈곤율 OECD 국가 중 1위',
#     'topic_keyword': '노인,고령,인구,가구,혼자,빈곤,빈곤율,2명,고령사회,166만,준비,3명,노후준비,노후,초고령사회,최고,비중,사회,35%,진입,3가구,고령인구,1위,독거노인,고령자,증가,상태,개월,건강,21개월,자연감소,국가,연명,혼자사,1인,5위,2025년,여파,19.8%,67%,20%,건강상태,부산,대도시,노인가구,감소,심화,인구절벽,기대수명,국민',
#     'topic_rank': 18},
#    {'news_cluster': ['02100201.20210929162234001',
#      '02100801.20210929153720001',
#      '02100311.20210929152535001',
#      '07101201.20210929151406001',
#      '01500701.20210929144440001',
#      '01100701.20210929143714001',
#      '02100601.20210929141231001',
#      '01100201.20210929124004001',
#      '08200101.20210929114849002',
#      '08100401.20210929113802005',
#      '01200201.20210929112352001',
#      '01100401.20210929111435001',
#      '01100901.20210929110120001',
#      '01100611.20210929102248001',
#      '02100701.20210929101909002',
#      '01500601.20210929100946001',
#      '02100601.20210929080912001'],
#     'topic': '중고차 관련 유튜버, 영종도 주차장서 피흘린 채 발견',
#     'topic_keyword': '유튜버,중고차,발견,중태,영종도,허위,매물,수술,허위매물,뇌수술,주차장,피해,피습,30대,살해,감형,지인,질문,머리,층간소음,소리,살해범,구속,중상,사과,영랑호,침묵,복수,실명,피해자,부인,의혹,흉기,노인,폭행,의식,고개,딜러,청와대,의사,시민,혐의,소음,출입,의도,헤럴드겨제,제작,당일,제2형사부,이날',
#     'topic_rank': 17},
#    {'news_cluster': ['02100701.20210929162005001',
#      '01101101.20210929161507001',
#      '01100701.20210929160925001',
#      '02100311.20210929153621001',
#      '02100601.20210929153447001',
#      '02100851.20210929153020001',
#      '08100401.20210929152802001',
#      '07100501.20210929152125001',
#      '01100101.20210929151428002',
#      '02100701.20210929151314001',
#      '02100201.20210929150849001',
#      '01101001.20210929150017002',
#      '02100801.20210929145419002',
#      '02100851.20210929144739001',
#      '02100311.20210929144147001',
#      '01100801.20210929143858001'],
#     'topic': 'BBQ, bhc 상대 1000억원대 소송 1심 패소',
#     'topic_keyword': 'bhc,소송,000억,패소,1000억,상대,영업비밀,비밀,원대,침해,1심,항소,치킨,영업비밀침해,전쟁,치킨전쟁,즉시,1천억,손배소,bhc상대,1라운드,치킨소송,밀리나,결과,1심서,소송전,승소,승자,4차,완승,박현종,승기,신청,지속,보호,다툼,지붕,국제상공회의소,책임,기밀,기각,투명,판단,수차례,공방,340억,불필요,판결,회사,의미',
#     'topic_rank': 16}]}}

# %% [markdown]
# # 5. 연관어 분석 API

# %%
url = 'http://tools.kinds.or.kr:8888/word_cloud'

datas = {
    "access_key": "9af2f705-2974-4340-8b55-d69040b944ab",

    "argument": {
        "query": "말레이 항공기 실종", 
        "published_at": {
                    "from": "2013-01-01",
                    "until": "2021-01-31"
                    },
        "provider": [],
        "category": [],
        "category_incident": [],
        "byline": "",
        "provider_subject": [ "국제" ] 
        }
}

response = requests.post(url, data=json.dumps(datas))
response.json()
# Out:
# {'result': 0,
#  'return_object': {'nodes': [{'id': 2,
#     'level': 1,
#     'name': '여객기',
#     'weight': 47.62},
#    {'id': 3, 'level': 3, 'name': 'MH370', 'weight': 42.52},
#    {'id': 4, 'level': 3, 'name': '인도양', 'weight': 35.73},
#    {'id': 6, 'level': 3, 'name': '중국', 'weight': 22.84},
#    {'id': 7, 'level': 3, 'name': '호주', 'weight': 20.37},
#    {'id': 8, 'level': 1, 'name': '승무원 239명', 'weight': 19.16},
#    {'id': 9, 'level': 1, 'name': '중국 베이징', 'weight': 17.31},
#    {'id': 10, 'level': 3, 'name': '수색작업', 'weight': 16.1},
#    {'id': 11, 'level': 3, 'name': '기자회견', 'weight': 12.44},
#    {'id': 12, 'level': 3, 'name': '조종사', 'weight': 10.32},
#    {'id': 13, 'level': 3, 'name': '쿠알라룸푸르', 'weight': 8.73},
#    {'id': 14, 'level': 3, 'name': '베트남 영공', 'weight': 5.74},
#    {'id': 15, 'level': 3, 'name': '보잉', 'weight': 4.71},
#    {'id': 16, 'level': 2, 'name': '인도네시아', 'weight': 13.33},
#    {'id': 17, 'level': 3, 'name': '사고기', 'weight': 10.37},
#    {'id': 18, 'level': 3, 'name': '싱가포르', 'weight': 10.23},
#    {'id': 19, 'level': 3, 'name': '에어아시아', 'weight': 8.08},
#    {'id': 20, 'level': 2, 'name': '위성사진', 'weight': 13.27},
#    {'id': 21, 'level': 3, 'name': '인공위성', 'weight': 8.05},
#    {'id': 22, 'level': 2, 'name': 'AP통신', 'weight': 11.55},
#    {'id': 23, 'level': 3, 'name': '항공사', 'weight': 9.08},
#    {'id': 24, 'level': 3, 'name': 'AP', 'weight': 7.41},
#    {'id': 25, 'level': 2, 'name': '토니 애벗 호주 총리', 'weight': 10.23},
#    {'id': 26, 'level': 3, 'name': '남중국해', 'weight': 8.53},
#    {'id': 27, 'level': 3, 'name': '외신들', 'weight': 7.12},
#    {'id': 28, 'level': 3, 'name': '신화통신', 'weight': 6.67},
#    {'id': 29, 'level': 3, 'name': '사고 원인', 'weight': 6.55},
#    {'id': 30, 'level': 3, 'name': 'CNN', 'weight': 6.48},
#    {'id': 31, 'level': 3, 'name': '부기장', 'weight': 5.68},
#    {'id': 32, 'level': 3, 'name': '아프리카 동부 인도양', 'weight': 6.08},
#    {'id': 33, 'level': 3, 'name': '전문가들', 'weight': 5.71},
#    {'id': 34, 'level': 3, 'name': '우크라이나 상공', 'weight': 5.33},
#    {'id': 35, 'level': 3, 'name': '조종석', 'weight': 4.5}]}}

# %% [markdown]
# # 6. 키워드 트렌드 API

# %%
url = 'http://tools.kinds.or.kr:8888/time_line'

datas = {
    "access_key": "9af2f705-2974-4340-8b55-d69040b944ab",

    "argument": {
        "query": "말레이 항공기", 
        "published_at": {
            "from": "2010-01-01",
            "until": "2018-12-31"
            },
        
        "provider": [""],
        "category": [""],
        "category_incident": [ ""],
        "byline": "", 
        "provider_subject": [""],
        "interval": "month", 
        "normalize": False,
        }
}

response = requests.post(url, data=json.dumps(datas))
response.json()

# %% [markdown]
# # 7. 인기검색어 API

# %%
url = 'http://tools.kinds.or.kr:8888/query_rank'

datas = {
    "access_key": "9af2f705-2974-4340-8b55-d69040b944ab",

    "argument": {
        "from": "2021-08-28",
        "until": "2021-08-29",
        "offset": 10,
        "target_access_key": ""
        }
}

response = requests.post(url, data=json.dumps(datas))
response.json()

# %% [markdown]
# # 8. 뉴스 인용문 검색 API

# %%
url = 'http://tools.kinds.or.kr:8888/search/quotation'

datas = {
    "access_key": "9af2f705-2974-4340-8b55-d69040b944ab",

    "argument": {
        "query": "말레이 항공기 실종, 영구 미제로…사고 원인 규명 못해", 
        "published_at": {
            "from": "2015-01-01",
            "until": "2021-03-30"
            },
        "provider": [ "한겨레" ],
        "category": [],
        "category_incident": [],
        "byline": "",
        "provider_subject": [""],
        "subject_info": [""],
        "subject_info1": [""],
        "subject_info2": [""],
        "subject_info3": [""],
        "subject_info4": [""], 
        "sort": {"date": "desc"},
        "hilight": 200,
        "return_from": 0,
        "return_size": 5,
        "fields": [
                   "hilight",
                   "byline",
                   "category",
                   "category_incident",
                   "images",
                   "provider_subject",
                   "subject_info",
                   "provider_news_id",
                   "publisher_code"
                   ]
                 }
}

response = requests.post(url, data=json.dumps(datas))
response.json()
# Out:
# {'result': 0,
#  'return_object': {'documents': [{'category': ['국제>아시아',
#      '국제>미국_북미',
#      '국제>유럽_EU'],
#     'category_incident': ['범죄>범죄일반>유괴/납치',
#      '사고>교통사고>항공사고',
#      '사고>교통사고>해상사고',
#      '사회>사회문제>자살'],
#     'date': '20180731',
#     'news_id': '01101001.20180731114940001',
#     'provider': '한겨레',
#     'provider_subject': [{'subject_info': '국제',
#       'subject_info1': '',
#       'subject_info2': '',
#       'subject_info3': '',
#       'subject_info4': ''}],
#     'published_at': '2018-07-31T00:00:00.000+09:00',
#     'publisher_code': '',
#     'quotation': '충분한 증거가 없어 이번 사건이 발생한 원인을 명확히 특정하지 못했다',
#     'source': '말레이시아 정부',
#     'subject_info': ['국제']},
#    {'category': ['국제>아시아', '국제>미국_북미', '국제>유럽_EU'],
#     'category_incident': ['범죄>범죄일반>유괴/납치',
#      '사고>교통사고>항공사고',
#      '사고>교통사고>해상사고',
#      '사회>사회문제>자살'],
#     'date': '20180731',
#     'news_id': '01101001.20180731114940001',
#     'provider': '한겨레',
#     'provider_subject': [{'subject_info': '국제',
#       'subject_info1': '',
#       'subject_info2': '',
#       'subject_info3': '',
#       'subject_info4': ''}],
#     'published_at': '2018-07-31T00:00:00.000+09:00',
#     'publisher_code': '',
#     'quotation': '이것이 최종 보고서라고 말하는 것은 너무 성급하다\n어떤 잔해도 발견되지 않았고, 희생자도 발견되지 않았다. 어떻게 이게 최종일 수 있는가',
#     'source': '콕 팀장',
#     'subject_info': ['국제']}],
#   'total_hits': 2}}

# %% [markdown]
# # 9. 오늘의 키워드 API

# %%
url = 'http://tools.kinds.or.kr:8888/today_category_keyword'

datas = {
    "access_key": "9af2f705-2974-4340-8b55-d69040b944ab",
    "argument": {}
}

response = requests.post(url, data=json.dumps(datas))
response.json()

# %% [markdown]
# # 10. 특성 추출 API

# %%
url = 'http://tools.kinds.or.kr:8888/feature'

datas = {
    "access_key": "9af2f705-2974-4340-8b55-d69040b944ab",
    "argument": {
        "title": "말레이 항공기 실종, 영구 미제로…사고 원인 규명 못해", 
        "sub_title": "말레이 항공기 실종, 영구 미제로…사고 원인 규명 못해", 
        "content": "운항 도중 흔적도 없이 사라진 ₩‘말레이시아항공 370₩’(MH-370) 여객기 실종 사건은 결국 항공 사상 최대 미스터리로 남게 됐다. \n\n 말레이시아 정부는 30일 펴낸 MH-370편 실종사건에 대한 495쪽에 달하는 공식 최종 보고서에서 ₩“충분한 증거가 없어 이번 사건이 발생한 원인을 명확히 특정하지 못했다₩”는 결론을 내렸다." 
        }
}

response = requests.post(url, data=json.dumps(datas))
response.json()
# Out:
# {'result': 0,
#  'return_object': {'result': {'content': '여객기_실종_사건|0.04274765808915152 여객기|0.042685630891976495 공식_최종|0.03994576771381414 여객기_실종|0.03904550652573918 공식_최종_보고서|0.03735339074298967 운항_도중|0.03552499328540658 사상_최대|0.03539176397945465 결국_항공|0.0350394066780242 운항_도중_흔적|0.034972605413764686 실종사건|0.03466234770964821 말레이시아항공|0.034434675376852936 말레이시아|0.03438954356143583 495쪽|0.034238882914484084 보고서|0.03363548263754353 말레이시아_정부|0.03176944275348782 사건|5.231486375853169E-4 도중|4.434264508774422E-4 최대|4.414341862408514E-4 공식|4.360287697008817E-4 최종|4.337255345968357E-4 결국|4.3360107994165934E-4 실종|4.233051543218841E-4 원인|3.5537487112921487E-4 정부|3.4785052517012356E-4 운항|3.4291487411625506E-4 흔적|3.4291006661381286E-4 사상|3.4182602767202113E-4 발생|3.411525225356049E-4 항공|3.4051366736684047E-4 미스터리|3.3749610338183197E-4 증거|3.3263401166157833E-4 특정|2.5221727622594273E-4',
#    'sub_title': '항공기|0.13790778810885904 말레이_항공기|0.11050265623013206 원인_규명|0.11050111004222837 말레이_항공기_실종|0.10879217984258269 원인_규명_못해|0.1087859821285097 말레이|0.10667907426986747 못해|0.10667088728044932 영구_미제|0.09863480946678656 원인|0.0013791216282848014 미제|0.0010777007115981413 영구|0.0010699229710391315 사고|0.0010698149477278759 실종|0.0010668509598285043 규명|0.0010667380945282726',
#    'title': '항공기|0.13790778810885904 말레이_항공기|0.11050265623013206 원인_규명|0.11050111004222837 말레이_항공기_실종|0.10879217984258269 원인_규명_못해|0.1087859821285097 말레이|0.10667907426986747 못해|0.10667088728044932 영구_미제|0.09863480946678656 원인|0.0013791216282848014 미제|0.0010777007115981413 영구|0.0010699229710391315 사고|0.0010698149477278759 실종|0.0010668509598285043 규명|0.0010667380945282726'}}}

# %% [markdown]
# # 11. 키워드 추출 API

# %%
url = 'http://tools.kinds.or.kr:8888/keyword'

datas = {
    "access_key": "9af2f705-2974-4340-8b55-d69040b944ab", 
    "argument": {
        "title": "말레이 항공기 실종, 영구 미제로…사고 원인 규명 못해", 
        "sub_title": "말레이 항공기 실종, 영구 미제로…사고 원인 규명 못해", 
        "content": "운항 도중 흔적도 없이 사라진 ‘말레이시아항공 370’(MH-370) 여객기 실종 사건은 결국 항공 사상 최대 미스터리로 남게 됐다. \n\n 말레이시아 정부는 30일 펴낸 MH-370편 실종사건에 대한 495쪽에 달하는 공식 최종 보고서에서 “충분한 증거가 없어 이번 사건이 발생한 원인을 명확히 특정하지 못했다”는 결론을 내렸다." 
        }
}

response = requests.post(url, data=json.dumps(datas))
response.json()
# Out:
# {'result': 0,
#  'return_object': {'result': {'content': '운항 도중 흔적 말레이시아항공 mh 여객기 실종 사건 결국 항공 사상 최대 미스터리 말레이시아 정부 30일 mh 370편 실종사건 495쪽 공식 최종 보고서 증거 사건 발생 원인 특정 ',
#    'sub_title': '말레이 항공기 실종 영구 미제 사고 원인 규명 못해 ',
#    'title': '말레이 항공기 실종 영구 미제 사고 원인 규명 못해 '}}}

# %% [markdown]
# # 12. TopN 키워드 API

# %%
# 유형 1
url = 'http://tools.kinds.or.kr:8888/topn_keyword'

datas = {
    "access_key": "9af2f705-2974-4340-8b55-d69040b944ab", 
    "argument": {
        "date_hour": "2018073100"
        }
}

response = requests.post(url, data=json.dumps(datas))
response.json()

# %%
# 유형 2
url = 'http://tools.kinds.or.kr:8888/topn_keyword'

datas = {
    "access_key": "9af2f705-2974-4340-8b55-d69040b944ab", 
    "argument": {
        "published_at": {
            "from": "2018-07-30",
            "until": "2018-07-31"
            },
        "query": "말레이", 
        "category": [
            "005000000",
            ] 
            }
}

response = requests.post(url, data=json.dumps(datas))
response.json()
# Out:
# {'result': 0,
#  'return_object': {'result': [{'name': '말레이시아', 'rank': '1'},
#    {'name': '보고서', 'rank': '2'},
#    {'name': '호주', 'rank': '3'},
#    {'name': '관광객', 'rank': '4'},
#    {'name': '캐나다', 'rank': '5'},
#    {'name': '롬복', 'rank': '6'},
#    {'name': '린자니', 'rank': '7'},
#    {'name': '링깃', 'rank': '8'},
#    {'name': '영주', 'rank': '9'},
#    {'name': '인도네시아', 'rank': '10'},
#    {'name': '인도양', 'rank': '11'},
#    {'name': '50세', 'rank': '12'},
#    {'name': '말레이시아인 관광객', 'rank': '13'},
#    {'name': '미국', 'rank': '14'},
#    {'name': '발리', 'rank': '15'},
#    {'name': '비행기', 'rank': '16'},
#    {'name': '사고 원인', 'rank': '17'},
#    {'name': '투자이민', 'rank': '18'},
#    {'name': '희망자', 'rank': '19'},
#    {'name': '1억', 'rank': '20'},
#    {'name': '4150만', 'rank': '21'},
#    {'name': 'MM2H', 'rank': '22'},
#    {'name': 'SC188', 'rank': '23'},
#    {'name': '관광지', 'rank': '24'},
#    {'name': '중국', 'rank': '25'},
#    {'name': '사업체', 'rank': '26'},
#    {'name': '아시아', 'rank': '27'},
#    {'name': '영주권 신청', 'rank': '28'},
#    {'name': '은퇴비자', 'rank': '29'},
#    {'name': '이민 적격자', 'rank': '30'},
#    {'name': '이민국', 'rank': '31'},
#    {'name': '자녀교육', 'rank': '32'},
#    {'name': '12만', 'rank': '33'},
#    {'name': '14개국 승객', 'rank': '34'},
#    {'name': '160여', 'rank': '35'},
#    {'name': '30만', 'rank': '36'},
#    {'name': 'EE', 'rank': '37'},
#    {'name': 'MH370편', 'rank': '38'},
#    {'name': 'MM2H 조건부', 'rank': '39'},
#    {'name': '가정집', 'rank': '40'},
#    {'name': '강진', 'rank': '41'},
#    {'name': '결국 영구', 'rank': '42'},
#    {'name': '경로 이탈', 'rank': '43'},
#    {'name': '공교육', 'rank': '44'},
#    {'name': '기업이민제도', 'rank': '45'},
#    {'name': '기자회견', 'rank': '46'},
#    {'name': '기장 자하리', 'rank': '47'},
#    {'name': '더스타', 'rank': '48'},
#    {'name': '동반 자살설', 'rank': '49'},
#    {'name': '말레이시아항공 MH370편', 'rank': '50'},
#    {'name': '미국 이민', 'rank': '51'},
#    {'name': '베이징', 'rank': '52'},
#    {'name': '베트남', 'rank': '53'},
#    {'name': '베트남 호찌민공항', 'rank': '54'},
#    {'name': '변호사 그레이스', 'rank': '55'},
#    {'name': '보람이주공사', 'rank': '56'},
#    {'name': '부상자', 'rank': '57'},
#    {'name': '비행 모의', 'rank': '58'},
#    {'name': '사람들', 'rank': '59'},
#    {'name': '사망자', 'rank': '60'},
#    {'name': '사업자등록증', 'rank': '61'},
#    {'name': '산사태', 'rank': '62'},
#    {'name': '순수투자이민 제도', 'rank': '63'},
#    {'name': '시민권자', 'rank': '64'},
#    {'name': '시아인', 'rank': '65'},
#    {'name': '실종자', 'rank': '66'},
#    {'name': '아메리카', 'rank': '67'},
#    {'name': '아흐마드', 'rank': '68'},
#    {'name': '영어능력', 'rank': '69'},
#    {'name': '오션인피티니', 'rank': '70'},
#    {'name': '외국인', 'rank': '71'},
#    {'name': '의료비', 'rank': '72'},
#    {'name': '이민 조건', 'rank': '73'},
#    {'name': '이민 희망자들', 'rank': '74'},
#    {'name': '자녀교육 워너비', 'rank': '75'},
#    {'name': '장기체류비자', 'rank': '76'},
#    {'name': '조사 책임자', 'rank': '77'},
#    {'name': '콕수촌', 'rank': '78'},
#    {'name': '퀘벡주', 'rank': '79'},
#    {'name': '태국', 'rank': '80'},
#    {'name': '투자금', 'rank': '81'},
#    {'name': '투자이민 최소 투자금', 'rank': '82'},
#    {'name': '프랑스', 'rank': '83'},
#    {'name': '필리핀', 'rank': '84'},
#    {'name': '한국', 'rank': '85'},
#    {'name': '15만', 'rank': '86'},
#    {'name': '18세', 'rank': '87'},
#    {'name': '21세', 'rank': '88'},
#    {'name': '275만', 'rank': '89'},
#    {'name': '2m 길이', 'rank': '90'},
#    {'name': '2~5%', 'rank': '91'},
#    {'name': '2가지', 'rank': '92'},
#    {'name': '2단계', 'rank': '93'},
#    {'name': '2단계 투자영주비자', 'rank': '94'},
#    {'name': '2억', 'rank': '95'},
#    {'name': '30여', 'rank': '96'},
#    {'name': '3가지', 'rank': '97'},
#    {'name': '495쪽', 'rank': '98'},
#    {'name': '60만', 'rank': '99'},
#    {'name': '60세', 'rank': '100'}]}}

# %% [markdown]
# # 13. 코드테이블
# ## 13.1 언론사

# %%
"""
01100101
경향신문
01100201
국민일보
01100301
내일신문
01100401
동아일보
01100501
문화일보
01100611
서울신문
01100701
세계일보
01100801
조선일보
01100901
중앙일보
01101001
한겨레
01101101
한국일보
01200101
경기일보
01200201
경인일보
01300101
강원도민일보
01300201
강원일보
01400201
대전일보
01400351
중도일보
01400401
중부매일
01400501
중부일보
01400551
충북일보
01400601
충청일보
01400701
충청투데이
01500051
경남신문
01500151
경남도민일보
01500301
경상일보
01500401
국제신문
01500501
대구일보
01500601
매일신문
01500701
부산일보
01500801
영남일보
01500901
울산매일
01600201
광주매일신문
01600301
광주일보
01600501
무등일보
01600801
전남일보
01601001
전북도민일보
01601101
전북일보
01700101
제민일보
01700201
한라일보
02100101
매일경제
02100201
머니투데이
02100311
서울경제
02100501
파이낸셜뉴스
02100601
한국경제
02100701
헤럴드경제
02100801
아시아경제
02100851
아주경제
07100501
전자신문
07101201
디지털타임스
08100101
KBS
08100201
MBC
08100301
SBS
08100401
YTN
08200101
OBS
"""

# %% [markdown]
# ## 13.2 뉴스 통합 분류체계

# %%
"""
정치
001000000
정치>북한
001001000
정치>선거
001002000
정치>외교
001003000
정치>국회_정당
001004000
정치>행정_자치
001005000
정치>청와대
001006000
정치>정치일반
001007000
경제
002000000
경제>무역
002001000
경제>외환
002002000
경제>유통
002003000
경제>자원
002004000
경제>산업_기업
002005000
경제>증권_증시
002006000
경제>취업_창업
002007000
경제>금융_재테크
002008000
경제>반도체
002009000
경제>부동산
002010000
경제>자동차
002011000
경제>서비스_쇼핑
002012000
경제>국제경제
002013000
경제>경제일반
002014000
사회
003000000
사회>날씨
003001000
사회>여성
003002000
사회>환경
003003000
사회>교육_시험
003004000
사회>노동_복지
003005000
사회>사건_사고
003006000
사회>의료_건강
003007000
사회>미디어
003008000
사회>장애인
003009000
사회>사회일반
003010000
문화
004000000
문화>생활
004001000
문화>영화
004002000
문화>음악
004003000
문화>종교
004004000
문화>출판
004005000
문화>미술_건축
004006000
문화>방송_연예
004007000
문화>요리_여행
004008000
문화>전시_공연
004009000
문화>학술_문화재
004010000
문화>문화일반
004011000
국제
005000000
국제>일본
005001000
국제>중국
005002000
국제>미국_북미
005003000
국제>중동_아프리카
005004000
국제>러시아
005005000
국제>아시아
005006000
국제>중남미
005007000
국제>유럽_EU
005008000
국제>국제일반
005009000
지역
006000000
지역>강원
006001000
지역>경기
006002000
지역>경남
006003000
지역>경북
006004000
지역>광주
006005000
지역>대구
006006000
지역>대전
006007000
지역>부산
006008000
지역>울산
006009000
지역>전남
006010000
지역>전북
006011000
지역>제주
006012000
지역>충남
006013000
지역>충북
006014000
지역>지역일반
006015000
스포츠
007000000
스포츠>골프
007001000
스포츠>야구
007002000
스포츠>야구>메이저리그
007002001
스포츠>야구>일본프로야구
007002002
스포츠>야구>한국프로야구
007002003
스포츠>축구
007003000
스포츠>축구>해외축구
007003001
스포츠>축구>국가대표팀
007003002
스포츠>축구>한국프로축구
007003003
스포츠>농구_배구
007005000
스포츠>월드컵
007006000
스포츠>올림픽_아시안게임
007010000
스포츠>스포츠일반
007013000
IT_과학
008000000
IT_과학>과학
008001000
IT_과학>보안
008002000
IT_과학>모바일
008003000
IT_과학>콘텐츠
008004000
IT_과학>인터넷_SNS
008005000
IT_과학>IT_과학일반
008006000
"""

# %% [markdown]
# ## 13.3 뉴스 사건/사고 분류체계

# %%
"""
범죄
1
범죄>성범죄
1,5
범죄>성범죄>성폭행
1,5,14
범죄>성범죄>성추행
1,5,15
범죄>성범죄>성희롱
1,5,16
범죄>성범죄>성매매
1,5,17
범죄>성범죄>음란물
1,5,18
범죄>기업범죄
1,6
범죄>기업범죄>반독점범죄
1,6,19
범죄>기업범죄>계약위반
1,6,20
범죄>기업범죄>횡령
1,6,21
범죄>기업범죄>내부자거래
1,6,22
범죄>기업범죄>거래제한
1,6,23
범죄>정치
1,7
범죄>정치>뇌물수수
1,7,24
범죄>범죄일반
1,8
범죄>범죄일반>방화
1,8,25
범죄>범죄일반>폭행
1,8,26
범죄>범죄일반>절도
1,8,27
범죄>범죄일반>유괴/납치
1,8,28
범죄>범죄일반>살인
1,8,29
범죄>범죄일반>사기
1,8,30
범죄>범죄일반>마약
1,8,31
사고
2
사고>산업사고
2,9
사고>산업사고>붕괴
2,9,32
사고>산업사고>폭발
2,9,33
사고>산업사고>화재
2,9,34
사고>산업사고>원자력사고
2,9,35
사고>교통사고
2,10
사고>교통사고>항공사고
2,10,36
사고>교통사고>우주사고
2,10,37
사고>교통사고>해상사고
2,10,38
사고>교통사고>철도사고
2,10,39
사고>교통사고>노상사고
2,10,40
재해
3
재해>자연재해
3,11
재해>자연재해>가뭄
3,11,41
재해>자연재해>지진
3,11,42
재해>자연재해>홍수
3,11,43
재해>자연재해>눈사태_산사태
3,11,44
재해>자연재해>태풍
3,11,45
재해>자연재해>폭염
3,11,46
재해>자연재해>해일
3,11,47
재해>자연재해>화산폭발
3,11,48
사회
4
사회>사회문제
4,12
사회>사회문제>학대
4,12,49
사회>사회문제>중독
4,12,50
사회>사회문제>미성년범죄
4,12,51
사회>사회문제>노예
4,12,52
사회>사회문제>자살
4,12,53
사회>사회갈등
4,13
사회>사회갈등>전쟁
4,13,54
사회>사회갈등>테러행위
4,13,55
사회>사회갈등>시위
4,13,56
사회>사회갈등>반란_혁명_폭동
4,13,57
사회>사회갈등>대량학살
4,13,58
"""
