# %%
import requests
import json
# "한겨레","조선일보","중앙일보","동아일보","경향신문","서울일보","KBS","MBC","SBS","YTN"

# %% [markdown]
# # 2. 뉴스 검색 API

# %%
url = 'http://tools.kinds.or.kr:8888/search/news'

datas = {
    "access_key": "9af2f705-2974-4340-8b55-d69040b944ab",

    "argument": {
        "query": {"title":""},
        "published_at": {
            "from": "2021-09-29",
            "until": "2021-10-06"
            },
            "provider": [],
            "category": ["001000000"],
            "category_incident": [""],
            "byline": "",
            "provider_subject": [""],
            "subject_info": [""],
            "subject_info1": [""],
            "subject_info2": [""],
            "subject_info3": [""],
            "subject_info4": [""],
            "sort": {"date": "asc"},
            "hilight": 200,
            "return_from": 0,
            "return_size": 100000,
            "fields": [
                "byline",
                "category",
                "category_incident",
                "provider_news_id",
                "hilight",
                ]
                }
         }

response = requests.post(url, data=json.dumps(datas))
js=response.json()

js

# %%
len(js['return_object']['documents'][0]['hilight'])
# Out:
# 205

# %% [markdown]
# # 3. 뉴스 상세정보 조회 API

# %%
url = 'http://tools.kinds.or.kr:8888/search/news'

datas = {
    "access_key": "9af2f705-2974-4340-8b55-d69040b944ab",

    "argument": {
        "news_ids": [
                    "01101001.20180731114940001",
                    ],
                
        "fields": [
                "content",
                "byline",
                "category",
                "category_incident",
                "images",
                "provider_subject",
                "provider_news_id",
                "publisher_code"
                ]
                }
 }

response = requests.post(url, data=json.dumps(datas))
response.json()
# Out:
# {'result': 0,
#  'return_object': {'documents': [{'byline': '정의길',
#     'category': ['국제>아시아', '국제>미국_북미', '국제>유럽_EU'],
#     'category_incident': ['범죄>범죄일반>유괴/납치',
#      '사고>교통사고>항공사고',
#      '사고>교통사고>해상사고',
#      '사회>사회문제>자살'],
#     'content': '운항 도중 흔적도 없이 사라진 ‘말레이시아항공 370’(MH-370) 여객기 실종 사건은 결국 항공 사상 최대 미스터리로 남게 됐다. \n\n 말레이시아 정부는 30일 펴낸 MH-370편 실종사건에 대한 495쪽에 달하는 공식 최종 보고서에서 “충분한 증거가 없어 이번 사건이 발생한 원인을 명확히 특정하지 못했다”는 결론을 내렸다. 이 보고서는 여객기 실종..',
#     'dateline': '2018-07-31T20:38:23.000+09:00',
#     'enveloped_at': '2018-07-31T11:49:40.000+09:00',
#     'images': '/01101001/2018/07/31/01101001.20180731114940001.01.jpg\n/01101001/2018/07/31/01101001.20180731114940001.02.jpg',
#     'news_id': '01101001.20180731114940001',
#     'provider': '한겨레',
#     'provider_news_id': '855582',
#     'provider_subject': [{'subject_info': '국제',
#       'subject_info1': '',
#       'subject_info2': '',
#       'subject_info3': '',
#       'subject_info4': ''}],
#     'published_at': '2018-07-31T00:00:00.000+09:00',
#     'publisher_code': '',
#     'title': '말레이 항공기 실종, 영구 미제로…사고 원인 규명 못해'}],
#   'total_hits': 1}}

# %% [markdown]
# # 4. 오늘의 이슈 API

# %%
url = 'http://tools.kinds.or.kr:8888/issue_ranking'

datas = {
    "access_key": "9af2f705-2974-4340-8b55-d69040b944ab",

    "argument": {
                "date": "2021-10-03",
                "provider": []
                }
}

response = requests.post(url, data=json.dumps(datas))
issue=response.json()

# %%
len(issue['return_object']['topics'])
# Out:
# 10

# %%
issue['return_object']['topics'][0].keys()
issue['return_object']['topics'][0]['topic']
#issue['return_object']['topics'][0]['topic_keyword']
# Out:
# '윤석열 "이재명, 후보 사퇴하고 특검 수사받아야"'

# %% [markdown]
# # 5. 연관어 분석 API

# %%
url = 'http://tools.kinds.or.kr:8888/word_cloud'

datas = {
    "access_key": "9af2f705-2974-4340-8b55-d69040b944ab",

    "argument": {
        "query": "대장동", 
        "published_at": {
                    "from": "2021-09-27",
                    "until": "2021-10-05"
                    },
        "provider": [],
        "category": [],
        "category_incident": [],
        "byline": "",
        "provider_subject": []
        }
}

response = requests.post(url, data=json.dumps(datas))
response.json()
# Out:
# {'result': 0,
#  'return_object': {'nodes': [{'id': 2,
#     'level': 1,
#     'name': '화천대유',
#     'weight': 66.26},
#    {'id': 3, 'level': 3, 'name': '이재명', 'weight': 51.25},
#    {'id': 4, 'level': 3, 'name': '유동규', 'weight': 45.16},
#    {'id': 5, 'level': 3, 'name': '성남도시개발공사', 'weight': 38.27},
#    {'id': 6, 'level': 3, 'name': '성남시', 'weight': 27.27},
#    {'id': 7, 'level': 3, 'name': '압수수색', 'weight': 24.99},
#    {'id': 8, 'level': 1, 'name': '이재명 경기지사', 'weight': 50.84},
#    {'id': 9, 'level': 1, 'name': '천화동', 'weight': 29.51},
#    {'id': 10, 'level': 3, 'name': '남욱 변호사', 'weight': 28.66},
#    {'id': 11, 'level': 3, 'name': '회계사', 'weight': 18.23},
#    {'id': 13, 'level': 2, 'name': '성남의뜰', 'weight': 22.05},
#    {'id': 14, 'level': 2, 'name': '특혜 의혹', 'weight': 22.02},
#    {'id': 15, 'level': 2, 'name': '검찰총장', 'weight': 20.27},
#    {'id': 16, 'level': 3, 'name': '더불어민주당', 'weight': 17.68},
#    {'id': 17, 'level': 3, 'name': '윤석열', 'weight': 17.52},
#    {'id': 18, 'level': 3, 'name': '이낙연', 'weight': 11.59},
#    {'id': 19, 'level': 2, 'name': '곽상도 의원', 'weight': 18.19},
#    {'id': 20, 'level': 3, 'name': '국민의힘', 'weight': 12.55},
#    {'id': 22, 'level': 3, 'name': '핵심 인물', 'weight': 17.65},
#    {'id': 23, 'level': 3, 'name': '정영학 회계사', 'weight': 13.61},
#    {'id': 24, 'level': 3, 'name': '민주당', 'weight': 13.25},
#    {'id': 25, 'level': 3, 'name': '성남도시개발공사 사장 직무대행', 'weight': 12.67},
#    {'id': 26, 'level': 3, 'name': '수사팀', 'weight': 12.24},
#    {'id': 27, 'level': 3, 'name': '사무실', 'weight': 12.12},
#    {'id': 28, 'level': 3, 'name': '화천대유자산관리', 'weight': 9.24},
#    {'id': 29, 'level': 3, 'name': '민간 사업자', 'weight': 11.84},
#    {'id': 30, 'level': 3, 'name': '페이스북', 'weight': 10.08},
#    {'id': 31, 'level': 3, 'name': '위례', 'weight': 8.53},
#    {'id': 32, 'level': 3, 'name': '자산관리회사', 'weight': 8.0}]}}

# %% [markdown]
# # 6. 키워드 트렌드 API

# %%
url = 'http://tools.kinds.or.kr:8888/time_line'

datas = {
    "access_key": "9af2f705-2974-4340-8b55-d69040b944ab",

    "argument": {
        "query": "말레이 항공기", 
        "published_at": {
            "from": "2010-01-01",
            "until": "2018-12-31"
            },
        
        "provider": [""],
        "category": [""],
        "category_incident": [ ""],
        "byline": "", 
        "provider_subject": [""],
        "interval": "month", 
        "normalize": False,
        }
}

response = requests.post(url, data=json.dumps(datas))
response.json()

# %% [markdown]
# # 7. 인기검색어 API

# %%
url = 'http://tools.kinds.or.kr:8888/query_rank'

datas = {
    "access_key": "9af2f705-2974-4340-8b55-d69040b944ab",

    "argument": {
        "from": "2021-10-04",
        "until": "2021-10-05",
        "offset": 20,
        "target_access_key": ""
        }
}

response = requests.post(url, data=json.dumps(datas))
response.json()
# Out:
# {'result': 0,
#  'return_object': {'queries': [{'count': 1919,
#     'date': '20211005',
#     'query': '이재명'},
#    {'count': 1599, 'date': '20211005', 'query': '윤석열'},
#    {'count': 1541, 'date': '20211005', 'query': '매각'},
#    {'count': 1539, 'date': '20211005', 'query': 'mrna'},
#    {'count': 1530, 'date': '20211005', 'query': '김동연'},
#    {'count': 1528, 'date': '20211005', 'query': '스마트스터디'},
#    {'count': 1526, 'date': '20211005', 'query': '디지털화폐'},
#    {'count': 1526, 'date': '20211005', 'query': '소형원전'},
#    {'count': 1525, 'date': '20211005', 'query': '테슬라'},
#    {'count': 1524, 'date': '20211005', 'query': '국책과제'},
#    {'count': 1523, 'date': '20211005', 'query': '예스24'},
#    {'count': 1523, 'date': '20211005', 'query': '여론조사'},
#    {'count': 1522, 'date': '20211005', 'query': '대란'},
#    {'count': 1519, 'date': '20211005', 'query': '국책사업'},
#    {'count': 1518, 'date': '20211005', 'query': '차지인'},
#    {'count': 1512, 'date': '20211005', 'query': '애플카'},
#    {'count': 1508, 'date': '20211005', 'query': '희토류'},
#    {'count': 1505, 'date': '20211005', 'query': '단독'},
#    {'count': 1505, 'date': '20211005', 'query': '카카오'},
#    {'count': 1494, 'date': '20211005', 'query': '인수'}]}}

# %% [markdown]
# # 8. 뉴스 인용문 검색 API

# %%
url = 'http://tools.kinds.or.kr:8888/search/quotation'

datas = {
    "access_key": "9af2f705-2974-4340-8b55-d69040b944ab",

    "argument": {
        "query": "말레이 항공기 실종, 영구 미제로…사고 원인 규명 못해", 
        "published_at": {
            "from": "2015-01-01",
            "until": "2021-03-30"
            },
        "provider": [ "한겨레" ],
        "category": [],
        "category_incident": [],
        "byline": "",
        "provider_subject": [""],
        "subject_info": [""],
        "subject_info1": [""],
        "subject_info2": [""],
        "subject_info3": [""],
        "subject_info4": [""], 
        "sort": {"date": "desc"},
        "hilight": 200,
        "return_from": 0,
        "return_size": 5,
        "fields": [
                   "hilight",
                   "byline",
                   "category",
                   "category_incident",
                   "images",
                   "provider_subject",
                   "subject_info",
                   "provider_news_id",
                   "publisher_code"
                   ]
                 }
}

response = requests.post(url, data=json.dumps(datas))
response.json()
# Out:
# {'result': 0,
#  'return_object': {'documents': [{'category': ['국제>아시아',
#      '국제>미국_북미',
#      '국제>유럽_EU'],
#     'category_incident': ['범죄>범죄일반>유괴/납치',
#      '사고>교통사고>항공사고',
#      '사고>교통사고>해상사고',
#      '사회>사회문제>자살'],
#     'date': '20180731',
#     'news_id': '01101001.20180731114940001',
#     'provider': '한겨레',
#     'provider_subject': [{'subject_info': '국제',
#       'subject_info1': '',
#       'subject_info2': '',
#       'subject_info3': '',
#       'subject_info4': ''}],
#     'published_at': '2018-07-31T00:00:00.000+09:00',
#     'publisher_code': '',
#     'quotation': '충분한 증거가 없어 이번 사건이 발생한 원인을 명확히 특정하지 못했다',
#     'source': '말레이시아 정부',
#     'subject_info': ['국제']},
#    {'category': ['국제>아시아', '국제>미국_북미', '국제>유럽_EU'],
#     'category_incident': ['범죄>범죄일반>유괴/납치',
#      '사고>교통사고>항공사고',
#      '사고>교통사고>해상사고',
#      '사회>사회문제>자살'],
#     'date': '20180731',
#     'news_id': '01101001.20180731114940001',
#     'provider': '한겨레',
#     'provider_subject': [{'subject_info': '국제',
#       'subject_info1': '',
#       'subject_info2': '',
#       'subject_info3': '',
#       'subject_info4': ''}],
#     'published_at': '2018-07-31T00:00:00.000+09:00',
#     'publisher_code': '',
#     'quotation': '이것이 최종 보고서라고 말하는 것은 너무 성급하다\n어떤 잔해도 발견되지 않았고, 희생자도 발견되지 않았다. 어떻게 이게 최종일 수 있는가',
#     'source': '콕 팀장',
#     'subject_info': ['국제']}],
#   'total_hits': 2}}

# %% [markdown]
# # 9. 오늘의 키워드 API

# %%
url = 'http://tools.kinds.or.kr:8888/today_category_keyword'

datas = {
    "access_key": "9af2f705-2974-4340-8b55-d69040b944ab",
    "argument": {}
}

response = requests.post(url, data=json.dumps(datas))
response.json()

# %% [markdown]
# # 10. 특성 추출 API

# %%
url = 'http://tools.kinds.or.kr:8888/feature'

datas = {
    "access_key": "9af2f705-2974-4340-8b55-d69040b944ab",
    "argument": {
        "title": "오징어 게임, 넷플릭스 세계 제패", 
        "sub_title": "말레이 항공기 실종, 영구 미제로…사고 원인 규명 못해", 
        "content": "운항 도중 흔적도 없이 사라진 ‘말레이시아항공 370’(MH-370) 여객기 실종 사건은 결국 항공 사상 최대 미스터리로 남게 됐다. \n\n 말레이시아 정부는 30일 펴낸 MH-370편 실종사건에 대한 495쪽에 달하는 공식 최종 보고서에서 “충분한 증거가 없어 이번 사건이 발생한 원인을 명확히 특정하지 못했다”는 결론을 내렸다" 
        }
}

response = requests.post(url, data=json.dumps(datas))
response.json()
# Out:
# {'result': 0,
#  'return_object': {'result': {'content': '여객기_실종_사건|0.04274765808915152 여객기|0.042685630891976495 공식_최종|0.03994576771381414 여객기_실종|0.03904550652573918 공식_최종_보고서|0.03735339074298967 운항_도중|0.03552499328540658 사상_최대|0.03539176397945465 결국_항공|0.0350394066780242 운항_도중_흔적|0.034972605413764686 실종사건|0.03466234770964821 말레이시아항공|0.034434675376852936 말레이시아|0.03438954356143583 495쪽|0.034238882914484084 보고서|0.03363548263754353 말레이시아_정부|0.03176944275348782 사건|5.231486375853169E-4 도중|4.434264508774422E-4 최대|4.414341862408514E-4 공식|4.360287697008817E-4 최종|4.337255345968357E-4 결국|4.3360107994165934E-4 실종|4.233051543218841E-4 원인|3.5537487112921487E-4 정부|3.4785052517012356E-4 운항|3.4291487411625506E-4 흔적|3.4291006661381286E-4 사상|3.4182602767202113E-4 발생|3.411525225356049E-4 항공|3.4051366736684047E-4 미스터리|3.3749610338183197E-4 증거|3.3263401166157833E-4 특정|2.5221727622594273E-4',
#    'sub_title': '항공기|0.13790778810885904 말레이_항공기|0.11050265623013206 원인_규명|0.11050111004222837 말레이_항공기_실종|0.10879217984258269 원인_규명_못해|0.1087859821285097 말레이|0.10667907426986747 못해|0.10667088728044932 영구_미제|0.09863480946678656 원인|0.0013791216282848014 미제|0.0010777007115981413 영구|0.0010699229710391315 사고|0.0010698149477278759 실종|0.0010668509598285043 규명|0.0010667380945282726',
#    'title': '넷플릭스|0.25004345933864314 넷플릭스_세계|0.19985804840935925 넷플릭스_세계_제패|0.19661989771267324 오징어_게임|0.15120769674346618 게임|0.0019787878357860377 세계|0.0019257280235853522 제패|0.0019256030121305079 오징어|0.0014092317875692838'}}}

# %% [markdown]
# # 11. 키워드 추출 API

# %%
url = 'http://tools.kinds.or.kr:8888/keyword'

datas = {
    "access_key": "9af2f705-2974-4340-8b55-d69040b944ab", 
    "argument": {
        "title": "오징어 게임, 넷플릭스 세계 제패", 
        "sub_title": "말레이 항공기 실종, 영구 미제로…사고 원인 규명 못해", 
        "content": "운항 도중 흔적도 없이 사라진 ‘말레이시아항공 370’(MH-370) 여객기 실종 사건은 결국 항공 사상 최대 미스터리로 남게 됐다. \n\n 말레이시아 정부는 30일 펴낸 MH-370편 실종사건에 대한 495쪽에 달하는 공식 최종 보고서에서 “충분한 증거가 없어 이번 사건이 발생한 원인을 명확히 특정하지 못했다”는 결론을 내렸다." 
        }
}

response = requests.post(url, data=json.dumps(datas))
response.json()
# Out:
# {'result': 0,
#  'return_object': {'result': {'content': '운항 도중 흔적 말레이시아항공 mh 여객기 실종 사건 결국 항공 사상 최대 미스터리 말레이시아 정부 30일 mh 370편 실종사건 495쪽 공식 최종 보고서 증거 사건 발생 원인 특정 ',
#    'sub_title': '말레이 항공기 실종 영구 미제 사고 원인 규명 못해 ',
#    'title': '오징어 게임 넷플릭스 세계 제패 '}}}

# %% [markdown]
# # 12. TopN 키워드 API

# %%
# 유형 1
url = 'http://tools.kinds.or.kr:8888/topn_keyword'

datas = {
    "access_key": "9af2f705-2974-4340-8b55-d69040b944ab", 
    "argument": {
        "date_hour": "2021100323"
        }
}

response = requests.post(url, data=json.dumps(datas))
response.json()
# Out:
# {'result': 0,
#  'return_object': {'result': [{'name': '이재명', 'rank': '1'},
#    {'name': '대장동', 'rank': '2'},
#    {'name': '확진자', 'rank': '3'},
#    {'name': '코로나19', 'rank': '4'},
#    {'name': '화천대유', 'rank': '5'},
#    {'name': '서울', 'rank': '6'},
#    {'name': '이낙연', 'rank': '7'},
#    {'name': '미국', 'rank': '8'},
#    {'name': '본부장', 'rank': '9'},
#    {'name': '인천', 'rank': '10'},
#    {'name': '윤석열', 'rank': '11'},
#    {'name': '한국', 'rank': '12'},
#    {'name': '유동규', 'rank': '13'},
#    {'name': '부산', 'rank': '14'},
#    {'name': '민주당', 'rank': '15'},
#    {'name': '코로나', 'rank': '16'},
#    {'name': '경기도', 'rank': '17'},
#    {'name': '김만배', 'rank': '18'},
#    {'name': '더불어민주당', 'rank': '19'},
#    {'name': '황희찬', 'rank': '20'},
#    {'name': '선거인단', 'rank': '21'},
#    {'name': '슈퍼위크', 'rank': '22'},
#    {'name': '손바닥', 'rank': '23'},
#    {'name': '대구', 'rank': '24'},
#    {'name': '중국', 'rank': '25'},
#    {'name': '이재명 후보', 'rank': '26'},
#    {'name': '대장동 의혹', 'rank': '27'},
#    {'name': '변호사', 'rank': '28'},
#    {'name': '홍준표', 'rank': '29'},
#    {'name': '이재명 지사', 'rank': '30'},
#    {'name': '부동산', 'rank': '31'},
#    {'name': '2차 슈퍼위크', 'rank': '32'},
#    {'name': '외국인', 'rank': '33'},
#    {'name': '토론회', 'rank': '34'},
#    {'name': '넷플릭스', 'rank': '35'},
#    {'name': '위원회', 'rank': '36'},
#    {'name': '수도권', 'rank': '37'},
#    {'name': '연천', 'rank': '38'},
#    {'name': '사람들', 'rank': '39'},
#    {'name': '성남도시개발공사', 'rank': '40'},
#    {'name': '경남', 'rank': '41'},
#    {'name': '광주', 'rank': '42'},
#    {'name': '1위', 'rank': '43'},
#    {'name': '일본', 'rank': '44'},
#    {'name': '지지자', 'rank': '45'},
#    {'name': '득표율', 'rank': '46'},
#    {'name': '백신 접종', 'rank': '47'},
#    {'name': '사업자', 'rank': '48'},
#    {'name': '제주', 'rank': '49'},
#    {'name': '군부대', 'rank': '50'},
#    {'name': '피해자', 'rank': '51'},
#    {'name': '2천', 'rank': '52'},
#    {'name': '당원', 'rank': '53'},
#    {'name': '추미애', 'rank': '54'},
#    {'name': '울산', 'rank': '55'},
#    {'name': '이재명 경기지사', 'rank': '56'},
#    {'name': 'TV', 'rank': '57'},
#    {'name': '100억', 'rank': '58'},
#    {'name': '경북', 'rank': '59'},
#    {'name': '오징어 게임', 'rank': '60'},
#    {'name': '이낙연 후보', 'rank': '61'},
#    {'name': '검찰총장', 'rank': '62'},
#    {'name': '성남', 'rank': '63'},
#    {'name': '年生', 'rank': '64'},
#    {'name': '대만', 'rank': '65'},
#    {'name': '문재인', 'rank': '66'},
#    {'name': '완료자', 'rank': '67'},
#    {'name': '위원장', 'rank': '68'},
#    {'name': '집단감염', 'rank': '69'},
#    {'name': '페이스북', 'rank': '70'},
#    {'name': '박용진', 'rank': '71'},
#    {'name': '2주', 'rank': '72'},
#    {'name': '구속영장', 'rank': '73'},
#    {'name': '대한민국', 'rank': '74'},
#    {'name': '성남시', 'rank': '75'},
#    {'name': 'SNS', 'rank': '76'},
#    {'name': '김씨', 'rank': '77'},
#    {'name': '전문가', 'rank': '78'},
#    {'name': '확산세', 'rank': '79'},
#    {'name': '2위', 'rank': '80'},
#    {'name': '곽상도', 'rank': '81'},
#    {'name': '전남', 'rank': '82'},
#    {'name': '유승민', 'rank': '83'},
#    {'name': '이씨', 'rank': '84'},
#    {'name': '박인비', 'rank': '85'},
#    {'name': '울버햄프턴', 'rank': '86'},
#    {'name': '고진영', 'rank': '87'},
#    {'name': '강원', 'rank': '88'},
#    {'name': '반도체', 'rank': '89'},
#    {'name': '홍준표 의원', 'rank': '90'},
#    {'name': 'LG', 'rank': '91'},
#    {'name': '국민들', 'rank': '92'},
#    {'name': '노동자', 'rank': '93'},
#    {'name': '돌파감염', 'rank': '94'},
#    {'name': '국민의힘', 'rank': '95'},
#    {'name': '영상편집', 'rank': '96'},
#    {'name': '지자체', 'rank': '97'},
#    {'name': '누적 득표율', 'rank': '98'},
#    {'name': '삼성', 'rank': '99'},
#    {'name': '서울시', 'rank': '100'}]}}

# %%
# 유형 2
url = 'http://tools.kinds.or.kr:8888/topn_keyword'

datas = {
    "access_key": "9af2f705-2974-4340-8b55-d69040b944ab", 
    "argument": {
        "published_at": {
            "from": "2021-10-04",
            "until": "2021-10-05"
            },
        "query": "오징어 게임", 
        "category": ["008000000"] 
            }
}

response = requests.post(url, data=json.dumps(datas))
response.json()
# Out:
# {'result': 0,
#  'return_object': {'result': [{'name': '넷플릭스', 'rank': '1'},
#    {'name': '한국', 'rank': '2'},
#    {'name': '오징어게임', 'rank': '3'},
#    {'name': '프랑스', 'rank': '4'},
#    {'name': '미국', 'rank': '5'},
#    {'name': '달고', 'rank': '6'},
#    {'name': '1위', 'rank': '7'},
#    {'name': '중국', 'rank': '8'},
#    {'name': '참가자', 'rank': '9'},
#    {'name': '이정재', 'rank': '10'},
#    {'name': '팰런쇼', 'rank': '11'},
#    {'name': '체험관', 'rank': '12'},
#    {'name': '83개국', 'rank': '13'},
#    {'name': '베이조스', 'rank': '14'},
#    {'name': '사람들', 'rank': '15'},
#    {'name': '팝업 스토어', 'rank': '16'},
#    {'name': '기생충', 'rank': '17'},
#    {'name': '한국 드라마', 'rank': '18'},
#    {'name': '456억', 'rank': '19'},
#    {'name': 'SNS', 'rank': '20'},
#    {'name': '넷플릭스 오리지널', 'rank': '21'},
#    {'name': 'TV', 'rank': '22'},
#    {'name': '시청자', 'rank': '23'},
#    {'name': 'OTT', 'rank': '24'},
#    {'name': '넷플릭스 드라마 오징어 게임', 'rank': '25'},
#    {'name': '소년단', 'rank': '26'},
#    {'name': 'NBC', 'rank': '27'},
#    {'name': '봉준호', 'rank': '28'},
#    {'name': '아마존', 'rank': '29'},
#    {'name': '정호연', 'rank': '30'},
#    {'name': '한국 콘텐츠', 'rank': '31'},
#    {'name': '드라마 오징어', 'rank': '32'},
#    {'name': '월스트리트저널', 'rank': '33'},
#    {'name': '오영수', 'rank': '34'},
#    {'name': '인스타그램', 'rank': '35'},
#    {'name': '삼양', 'rank': '36'},
#    {'name': '서바이벌 게임', 'rank': '37'},
#    {'name': '짜파구리', 'rank': '38'},
#    {'name': '구슬치기', 'rank': '39'},
#    {'name': '넷플릭스 드라마', 'rank': '40'},
#    {'name': '방문객', 'rank': '41'},
#    {'name': '주식 시장', 'rank': '42'},
#    {'name': 'WSJ', 'rank': '43'},
#    {'name': '삼양라면', 'rank': '44'},
#    {'name': '유통업', 'rank': '45'},
#    {'name': '제프', 'rank': '46'},
#    {'name': '플릭스패트롤', 'rank': '47'},
#    {'name': '넷플릭스 프랑스', 'rank': '48'},
#    {'name': '아마존 창업자', 'rank': '49'},
#    {'name': '아시아', 'rank': '50'},
#    {'name': '위하준', 'rank': '51'},
#    {'name': '일남', 'rank': '52'},
#    {'name': '제작사', 'rank': '53'},
#    {'name': '창업자', 'rank': '54'},
#    {'name': '출연진', 'rank': '55'},
#    {'name': '트위', 'rank': '56'},
#    {'name': '관람객', 'rank': '57'},
#    {'name': '돼지저금통', 'rank': '58'},
#    {'name': '스타링', 'rank': '59'},
#    {'name': '시리즈 오징어', 'rank': '60'},
#    {'name': '알렉산드리아', 'rank': '61'},
#    {'name': '진행요원', 'rank': '62'},
#    {'name': '청커페', 'rank': '63'},
#    {'name': '코로나19', 'rank': '64'},
#    {'name': '구글', 'rank': '65'},
#    {'name': '영국', 'rank': '66'},
#    {'name': '평론가', 'rank': '67'},
#    {'name': '히트작', 'rank': '68'},
#    {'name': '광고비', 'rank': '69'},
#    {'name': '기훈', 'rank': '70'},
#    {'name': '깐부', 'rank': '71'},
#    {'name': '박해수', 'rank': '72'},
#    {'name': '세계적 인기', 'rank': '73'},
#    {'name': '웨이보', 'rank': '74'},
#    {'name': '유튜브', 'rank': '75'},
#    {'name': '이재명', 'rank': '76'},
#    {'name': '인앱', 'rank': '77'},
#    {'name': '일본', 'rank': '78'},
#    {'name': '황동혁', 'rank': '79'},
#    {'name': '2위', 'rank': '80'},
#    {'name': '8200만', 'rank': '81'},
#    {'name': 'BTS', 'rank': '82'},
#    {'name': 'CNN', 'rank': '83'},
#    {'name': '가디언', 'rank': '84'},
#    {'name': '국제화 전략', 'rank': '85'},
#    {'name': '달 무료 이용권', 'rank': '86'},
#    {'name': '더우', 'rank': '87'},
#    {'name': '데스', 'rank': '88'},
#    {'name': '덴마크', 'rank': '89'},
#    {'name': '딱지치기', 'rank': '90'},
#    {'name': '발리우드', 'rank': '91'},
#    {'name': '봉고파직', 'rank': '92'},
#    {'name': '소셜', 'rank': '93'},
#    {'name': '소품들', 'rank': '94'},
#    {'name': '순위 1위', 'rank': '95'},
#    {'name': '인기 토크쇼', 'rank': '96'},
#    {'name': '인산인해', 'rank': '97'},
#    {'name': '터키', 'rank': '98'},
#    {'name': '틱톡', 'rank': '99'},
#    {'name': '한국 영화', 'rank': '100'}]}}

# %% [markdown]
# # 13. 코드테이블
# ## 13.1 언론사

# %%
"""
01100101
경향신문
01100201
국민일보
01100301
내일신문
01100401
동아일보
01100501
문화일보
01100611
서울신문
01100701
세계일보
01100801
조선일보
01100901
중앙일보
01101001
한겨레
01101101
한국일보
01200101
경기일보
01200201
경인일보
01300101
강원도민일보
01300201
강원일보
01400201
대전일보
01400351
중도일보
01400401
중부매일
01400501
중부일보
01400551
충북일보
01400601
충청일보
01400701
충청투데이
01500051
경남신문
01500151
경남도민일보
01500301
경상일보
01500401
국제신문
01500501
대구일보
01500601
매일신문
01500701
부산일보
01500801
영남일보
01500901
울산매일
01600201
광주매일신문
01600301
광주일보
01600501
무등일보
01600801
전남일보
01601001
전북도민일보
01601101
전북일보
01700101
제민일보
01700201
한라일보
02100101
매일경제
02100201
머니투데이
02100311
서울경제
02100501
파이낸셜뉴스
02100601
한국경제
02100701
헤럴드경제
02100801
아시아경제
02100851
아주경제
07100501
전자신문
07101201
디지털타임스
08100101
KBS
08100201
MBC
08100301
SBS
08100401
YTN
08200101
OBS
"""

# %% [markdown]
# ## 13.2 뉴스 통합 분류체계

# %%
"""
정치
001000000
정치>북한
001001000
정치>선거
001002000
정치>외교
001003000
정치>국회_정당
001004000
정치>행정_자치
001005000
정치>청와대
001006000
정치>정치일반
001007000
경제
002000000
경제>무역
002001000
경제>외환
002002000
경제>유통
002003000
경제>자원
002004000
경제>산업_기업
002005000
경제>증권_증시
002006000
경제>취업_창업
002007000
경제>금융_재테크
002008000
경제>반도체
002009000
경제>부동산
002010000
경제>자동차
002011000
경제>서비스_쇼핑
002012000
경제>국제경제
002013000
경제>경제일반
002014000
사회
003000000
사회>날씨
003001000
사회>여성
003002000
사회>환경
003003000
사회>교육_시험
003004000
사회>노동_복지
003005000
사회>사건_사고
003006000
사회>의료_건강
003007000
사회>미디어
003008000
사회>장애인
003009000
사회>사회일반
003010000
문화
004000000
문화>생활
004001000
문화>영화
004002000
문화>음악
004003000
문화>종교
004004000
문화>출판
004005000
문화>미술_건축
004006000
문화>방송_연예
004007000
문화>요리_여행
004008000
문화>전시_공연
004009000
문화>학술_문화재
004010000
문화>문화일반
004011000
국제
005000000
국제>일본
005001000
국제>중국
005002000
국제>미국_북미
005003000
국제>중동_아프리카
005004000
국제>러시아
005005000
국제>아시아
005006000
국제>중남미
005007000
국제>유럽_EU
005008000
국제>국제일반
005009000
지역
006000000
지역>강원
006001000
지역>경기
006002000
지역>경남
006003000
지역>경북
006004000
지역>광주
006005000
지역>대구
006006000
지역>대전
006007000
지역>부산
006008000
지역>울산
006009000
지역>전남
006010000
지역>전북
006011000
지역>제주
006012000
지역>충남
006013000
지역>충북
006014000
지역>지역일반
006015000
스포츠
007000000
스포츠>골프
007001000
스포츠>야구
007002000
스포츠>야구>메이저리그
007002001
스포츠>야구>일본프로야구
007002002
스포츠>야구>한국프로야구
007002003
스포츠>축구
007003000
스포츠>축구>해외축구
007003001
스포츠>축구>국가대표팀
007003002
스포츠>축구>한국프로축구
007003003
스포츠>농구_배구
007005000
스포츠>월드컵
007006000
스포츠>올림픽_아시안게임
007010000
스포츠>스포츠일반
007013000
IT_과학
008000000
IT_과학>과학
008001000
IT_과학>보안
008002000
IT_과학>모바일
008003000
IT_과학>콘텐츠
008004000
IT_과학>인터넷_SNS
008005000
IT_과학>IT_과학일반
008006000
"""

# %% [markdown]
# ## 13.3 뉴스 사건/사고 분류체계

# %%
"""
범죄
1
범죄>성범죄
1,5
범죄>성범죄>성폭행
1,5,14
범죄>성범죄>성추행
1,5,15
범죄>성범죄>성희롱
1,5,16
범죄>성범죄>성매매
1,5,17
범죄>성범죄>음란물
1,5,18
범죄>기업범죄
1,6
범죄>기업범죄>반독점범죄
1,6,19
범죄>기업범죄>계약위반
1,6,20
범죄>기업범죄>횡령
1,6,21
범죄>기업범죄>내부자거래
1,6,22
범죄>기업범죄>거래제한
1,6,23
범죄>정치
1,7
범죄>정치>뇌물수수
1,7,24
범죄>범죄일반
1,8
범죄>범죄일반>방화
1,8,25
범죄>범죄일반>폭행
1,8,26
범죄>범죄일반>절도
1,8,27
범죄>범죄일반>유괴/납치
1,8,28
범죄>범죄일반>살인
1,8,29
범죄>범죄일반>사기
1,8,30
범죄>범죄일반>마약
1,8,31
사고
2
사고>산업사고
2,9
사고>산업사고>붕괴
2,9,32
사고>산업사고>폭발
2,9,33
사고>산업사고>화재
2,9,34
사고>산업사고>원자력사고
2,9,35
사고>교통사고
2,10
사고>교통사고>항공사고
2,10,36
사고>교통사고>우주사고
2,10,37
사고>교통사고>해상사고
2,10,38
사고>교통사고>철도사고
2,10,39
사고>교통사고>노상사고
2,10,40
재해
3
재해>자연재해
3,11
재해>자연재해>가뭄
3,11,41
재해>자연재해>지진
3,11,42
재해>자연재해>홍수
3,11,43
재해>자연재해>눈사태_산사태
3,11,44
재해>자연재해>태풍
3,11,45
재해>자연재해>폭염
3,11,46
재해>자연재해>해일
3,11,47
재해>자연재해>화산폭발
3,11,48
사회
4
사회>사회문제
4,12
사회>사회문제>학대
4,12,49
사회>사회문제>중독
4,12,50
사회>사회문제>미성년범죄
4,12,51
사회>사회문제>노예
4,12,52
사회>사회문제>자살
4,12,53
사회>사회갈등
4,13
사회>사회갈등>전쟁
4,13,54
사회>사회갈등>테러행위
4,13,55
사회>사회갈등>시위
4,13,56
사회>사회갈등>반란_혁명_폭동
4,13,57
사회>사회갈등>대량학살
4,13,58
"""
